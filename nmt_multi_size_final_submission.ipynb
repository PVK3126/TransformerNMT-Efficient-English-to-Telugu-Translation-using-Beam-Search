# %% [markdown]
# # Multi-Size NMT Final Models (10M, 30M, 50M, 60M)
#
# This notebook redefines a readable Transformer NMT architecture, validates parameter targets, trains across model sizes with size-specific batch policies, and saves final checkpoints as `final_{x}m_model.pt`.

# %%
import gc
import json
import math
import os
import random
import time
from pathlib import Path

import numpy as np
import pandas as pd
import sentencepiece as spm
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, Sampler

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = False
torch.backends.cudnn.benchmark = True

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if DEVICE.type == "cuda":
    props = torch.cuda.get_device_properties(0)
    if hasattr(torch.backends, "cuda") and hasattr(torch.backends.cuda, "matmul"):
        torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True
    if hasattr(torch, "set_float32_matmul_precision"):
        torch.set_float32_matmul_precision("high")
    print(f"GPU: {torch.cuda.get_device_name(0)} | VRAM: {props.total_memory / 1e9:.1f} GB")
    print(
        f"TF32 matmul={getattr(torch.backends.cuda.matmul, 'allow_tf32', False)} | "
        f"cuDNN benchmark={torch.backends.cudnn.benchmark}"
    )
# Out:
# Device: cuda
# GPU: NVIDIA GeForce RTX 5060 Ti | VRAM: 16.6 GB
# TF32 matmul=True | cuDNN benchmark=True

# %%
# Define where data, cache, and trained models (checkpoints) will be stored
DATA_DIR = Path(".")
CACHE_DIR = DATA_DIR / "cache"
CHECKPOINT_DIR = CACHE_DIR / "checkpoints"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)  # create folder if not exists

# Tokenization Settings
# Vocabulary size and maximum sequence length used by the model
VOCAB_SIZE = 32000
MAX_SEQ_LEN = 128

# Special tokens used in sequence modeling
PAD_ID, UNK_ID, BOS_ID, EOS_ID = 0, 1, 2, 3

# --- Tokenizer Training (Patch) ---
# If the tokenizer doesn't exist, we can train it from the parquet files.
import pyarrow.parquet as pq

MODEL_PREFIX = str(CACHE_DIR / "nmt_unigram_v1_32000")
EXPECTED_MODEL = CACHE_DIR / "nmt_unigram_v1_32000.model"

if not EXPECTED_MODEL.exists():
    print("Tokenizer not found. Training a new Unigram model from parquet files...")
    
    # 1. Export sample text to a temporary text file for SentencePiece
    temp_txt_path = CACHE_DIR / "spm_train.txt"
    parquet_files = sorted(DATA_DIR.glob("train-*.parquet"))
    
    # Extract lines to train the tokenizer 
    max_lines_for_spm = 1_000_000
    lines_written = 0
    
    with open(temp_txt_path, "w", encoding="utf-8") as f:
        for p_file in parquet_files:
            if lines_written >= max_lines_for_spm:
                break
            table = pq.read_table(str(p_file), columns=["src", "tgt"])
            for src, tgt in zip(table["src"].to_pylist(), table["tgt"].to_pylist()):
                if src and tgt:
                    f.write(src.strip() + "\n")
                    f.write(tgt.strip() + "\n")
                    lines_written += 2
                    if lines_written >= max_lines_for_spm:
                        break
                        
    # 2. Train the SentencePiece model
    print(f"Extracted {lines_written} lines. Training SentencePiece...")
    spm.SentencePieceTrainer.train(
        input=str(temp_txt_path),
        model_prefix=MODEL_PREFIX,
        vocab_size=VOCAB_SIZE,
        model_type='unigram',
        character_coverage=0.9995,
        pad_id=PAD_ID, unk_id=UNK_ID, bos_id=BOS_ID, eos_id=EOS_ID,
        pad_piece="<pad>", unk_piece="<unk>", bos_piece="<s>", eos_piece="</s>"
    )
    print(f"Tokenizer trained successfully: {EXPECTED_MODEL}")
    
    # 3. Clean up the temp file
    if temp_txt_path.exists():
        temp_txt_path.unlink()


# Tokenizer Loading
# Try loading a pre-trained SentencePiece tokenizer (unigram or BPE)
TOKENIZER_CANDIDATES = [
    CACHE_DIR / "nmt_unigram_v1_32000.model",
    CACHE_DIR / "nmt_bpe.model",
]

# Pick the first available tokenizer file
SP_MODEL_PATH = next((p for p in TOKENIZER_CANDIDATES if p.exists()), None)

# Fail early if tokenizer is missing (important for reproducibility)
if SP_MODEL_PATH is None:
    raise FileNotFoundError("No tokenizer model found in cache/")

# Load tokenizer → converts text ↔ tokens
sp = spm.SentencePieceProcessor(model_file=str(SP_MODEL_PATH))


# ---------- Model Size Targets ----------
# We train multiple models to study scaling effects
TARGET_MILLIONS = [10, 30, 50, 60]


# ---------- Batch Policy (Memory Management) ----------
# Each model size uses different batch settings to fit GPU memory
BATCH_POLICY = {
    "10M": {"max_tokens": 9000, "grad_accum": 2},
    "30M": {"max_tokens": 6200, "grad_accum": 4},
    "50M": {"max_tokens": 4400, "grad_accum": 6},
    "60M": {"max_tokens": 3200, "grad_accum": 8},
}
# Key idea: larger models → smaller batches → more gradient accumulation


# Training Configuration
# Global hyperparameters controlling training behavior
TRAINING_DEFAULTS = {
    "epochs_per_model": 20,                # how many times we train over dataset
    "max_train_batches_per_epoch": 7000,  # limit batches (for faster experiments)
    "max_val_batches": 20,                # limit validation batches

    "lr": 5e-4,                           # learning rate
    "warmup_steps": 3000,                 # gradual LR increase at start
    "weight_decay": 0.01,                 # regularization to prevent overfitting
    "label_smoothing": 0.1,               # prevents overconfidence
    "grad_clip": 1.0,                     # avoids exploding gradients

    "use_amp": DEVICE.type == "cuda",     # mixed precision for faster GPU training

    "target_tokens_per_sec": 100_000,     # performance target (speed)
    "oom_retry_limit": 6,                 # max retries if GPU runs out of memory

    "min_max_tokens": 1024,               # minimum batch size limit
    "auto_batch_shrink_factor": 0.85,     # reduce batch size if OOM
    "max_grad_accum": 20,                 # limit gradient accumulation

    "num_workers": min(8, os.cpu_count() or 1),  # parallel data loading
    "prefetch_factor": 2,                 # improves data loading speed
}


# Logging (Important for Explanation)
print(f"Tokenizer: {SP_MODEL_PATH.name} | vocab={sp.get_piece_size()}")

print("Targets:", TARGET_MILLIONS)

print("Batch policy:", BATCH_POLICY)

print(
    f"Perf target: {TRAINING_DEFAULTS['target_tokens_per_sec']:,} tok/s | "
    f"OOM retries/model: {TRAINING_DEFAULTS['oom_retry_limit']} | "
    f"workers={TRAINING_DEFAULTS['num_workers']}"
)
# Out:
# Tokenizer: nmt_unigram_v1_32000.model | vocab=32000
# Targets: [10, 30, 50, 60]
# Batch policy: {'10M': {'max_tokens': 9000, 'grad_accum': 2}, '30M': {'max_tokens': 6200, 'grad_accum': 4}, '50M': {'max_tokens': 4400, 'grad_accum': 6}, '60M': {'max_tokens': 3200, 'grad_accum': 8}}
# Perf target: 100,000 tok/s | OOM retries/model: 6 | workers=8

# %%
def count_parameters(model: nn.Module) -> dict:
    # Counts how large the model is (important for comparing model sizes)
    # Total parameters in the model (all weights)
    total = sum(p.numel() for p in model.parameters())
    
    # Trainable parameters (only those updated during training)
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    # Return both values for analysis
    return {"total": total, "trainable": trainable}


def budget_report(model_name: str, target_m: int, actual_params: int) -> dict:
    # Compares expected model size vs actual parameter count
    # Convert target from millions to exact number
    target_params = int(target_m * 1_000_000)
    
    # Calculate difference between actual and target
    abs_err = actual_params - target_params
    
    # Percentage error (how far we are from target size)
    pct_err = (abs_err / target_params) * 100.0
    
    # Store results in structured format
    report = {
        "model": model_name,
        "target_m": target_m,
        "target_params": target_params,
        "actual_params": actual_params,
        "abs_error": abs_err,
        "pct_error": pct_err,
    }
    
    # Print summary → useful during training/debugging
    print(
        f"{model_name}: target={target_params:,} | actual={actual_params:,} | "
        f"error={abs_err:+,} ({pct_err:+.2f}%)"
    )
    
    return report
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dbb8b9d58000> in <module>
# ----> 1 def count_parameters(model: nn.Module) -> dict:
#       2     total = sum(p.numel() for p in model.parameters())
#       3     trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
#       4     return {"total": total, "trainable": trainable}
#       5
#
# NameError: name 'nn' is not defined

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model: int, max_len: int = 1024, dropout: float = 0.1):
        super().__init__()
        self.dropout = nn.Dropout(dropout)

        # Create positional encoding matrix to inject word order information
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len).unsqueeze(1).float()

        # Different frequencies for each dimension
        div = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)

        # Register as buffer → not trainable but stored in model
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Add positional encoding to embeddings
        return self.dropout(x + self.pe[:, : x.size(1)])


class EncoderStack(nn.Module):
    def __init__(self, d_model: int, nhead: int, d_ff: int, num_layers: int, dropout: float):
        super().__init__()

        # One encoder layer: self-attention + feedforward network
        layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=d_ff,
            dropout=dropout,
            batch_first=True,
            norm_first=True,
        )

        # Stack multiple encoder layers
        self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)

    def forward(self, x: torch.Tensor, src_key_padding_mask: torch.Tensor) -> torch.Tensor:
        # Process input sequence while ignoring padding tokens
        return self.encoder(x, src_key_padding_mask=src_key_padding_mask)


class DecoderStack(nn.Module):
    def __init__(self, d_model: int, nhead: int, d_ff: int, num_layers: int, dropout: float):
        super().__init__()

        # One decoder layer: self-attention + cross-attention + feedforward
        layer = nn.TransformerDecoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=d_ff,
            dropout=dropout,
            batch_first=True,
            norm_first=True,
        )

        # Stack multiple decoder layers
        self.decoder = nn.TransformerDecoder(layer, num_layers=num_layers)
        
    def forward(
        self,
        tgt: torch.Tensor,
        memory: torch.Tensor,
        tgt_mask: torch.Tensor,
        tgt_key_padding_mask: torch.Tensor,
        memory_key_padding_mask: torch.Tensor,
    ) -> torch.Tensor:
        # Generate output using encoder outputs (memory)
        return self.decoder(
            tgt=tgt,
            memory=memory,
            tgt_mask=tgt_mask,  # prevents seeing future tokens
            tgt_key_padding_mask=tgt_key_padding_mask,
            memory_key_padding_mask=memory_key_padding_mask,
        )


class NMTTrans(nn.Module):
    def __init__(self, vocab_size: int, d_model: int, nhead: int, num_enc_layers: int, num_dec_layers: int, d_ff: int, dropout: float = 0.1):
        super().__init__()

        self.d_model = d_model
        self.scale = math.sqrt(d_model)  # scale embeddings (stabilizes training)

        # Convert token IDs → dense vectors
        self.embedding = nn.Embedding(vocab_size, d_model, padding_idx=PAD_ID)

        # Add positional information
        self.position = PositionalEncoding(d_model=d_model, max_len=MAX_SEQ_LEN, dropout=dropout)

        # Encoder and decoder
        self.encoder = EncoderStack(d_model=d_model, nhead=nhead, d_ff=d_ff, num_layers=num_enc_layers, dropout=dropout)
        self.decoder = DecoderStack(d_model=d_model, nhead=nhead, d_ff=d_ff, num_layers=num_dec_layers, dropout=dropout)

        # Final layer → maps to vocabulary probabilities
        self.lm_head = nn.Linear(d_model, vocab_size, bias=False)

        # Weight tying → reduces parameters and improves performance
        self.lm_head.weight = self.embedding.weight

        self._init_weights()

    def _init_weights(self) -> None:
        # Xavier initialization for stable gradients
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self, src: torch.Tensor, tgt: torch.Tensor) -> torch.Tensor:
        # Create masks to ignore padding tokens
        src_pad_mask = src.eq(PAD_ID)
        tgt_pad_mask = tgt.eq(PAD_ID)

        # Prevent decoder from accessing future words (causal masking)
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(tgt.size(1), device=tgt.device)

        # Convert tokens → embeddings + add positional info
        src_emb = self.position(self.embedding(src) * self.scale)
        tgt_emb = self.position(self.embedding(tgt) * self.scale)

        # Encoder processes source sentence
        memory = self.encoder(src_emb, src_key_padding_mask=src_pad_mask)

        # Decoder generates output using encoder memory
        decoded = self.decoder(
            tgt=tgt_emb,
            memory=memory,
            tgt_mask=tgt_mask,
            tgt_key_padding_mask=tgt_pad_mask,
            memory_key_padding_mask=src_pad_mask,
        )

        # Output probabilities over vocabulary
        return self.lm_head(decoded)

# %%
MODEL_CONFIGS = {
    "10M": dict(d_model=256, nhead=4, num_enc_layers=3, num_dec_layers=3, d_ff=1024, dropout=0.10),
    "30M": dict(d_model=512, nhead=8, num_enc_layers=4, num_dec_layers=4, d_ff=2048, dropout=0.10),
    "50M": dict(d_model=512, nhead=8, num_enc_layers=6, num_dec_layers=6, d_ff=2304, dropout=0.10),
    "60M": dict(d_model=640, nhead=8, num_enc_layers=6, num_dec_layers=6, d_ff=2560, dropout=0.12),
}

model_10m = NMTTrans(vocab_size=VOCAB_SIZE, **MODEL_CONFIGS["10M"]).to(DEVICE)
params_10m = count_parameters(model_10m)["total"]
report_10m = budget_report("10M", 10, params_10m)
# Out:
# 10M: target=10,000,000 | actual=13,721,600 | error=+3,721,600 (+37.22%)
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)

# %%
model_30m = NMTTrans(vocab_size=VOCAB_SIZE, **MODEL_CONFIGS["30M"]).to(DEVICE)
params_30m = count_parameters(model_30m)["total"]
report_30m = budget_report("30M", 30, params_30m)
# Out:
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 30M: target=30,000,000 | actual=45,809,664 | error=+15,809,664 (+52.70%)

# %%
model_50m = NMTTrans(vocab_size=VOCAB_SIZE, **MODEL_CONFIGS["50M"]).to(DEVICE)
params_50m = count_parameters(model_50m)["total"]
report_50m = budget_report("50M", 50, params_50m)
# Out:
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 50M: target=50,000,000 | actual=63,671,296 | error=+13,671,296 (+27.34%)

# %%
model_60m = NMTTrans(vocab_size=VOCAB_SIZE, **MODEL_CONFIGS["60M"]).to(DEVICE)
params_60m = count_parameters(model_60m)["total"]
report_60m = budget_report("60M", 60, params_60m)
# Out:
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 60M: target=60,000,000 | actual=89,415,680 | error=+29,415,680 (+49.03%)

# %%
def auto_adjust_config(model_name: str, cfg: dict, target_m: int, tolerance_pct: float = 2.0) -> tuple[dict, dict]:
    tuned = dict(cfg)
    for _ in range(12):
        m = NMTTrans(vocab_size=VOCAB_SIZE, **tuned)
        actual = count_parameters(m)["total"]
        del m
        gc.collect()

        rpt = budget_report(model_name, target_m, actual)
        if abs(rpt["pct_error"]) <= tolerance_pct:
            return tuned, rpt

        if actual < rpt["target_params"]:
            tuned["d_ff"] += 128
        else:
            tuned["d_ff"] = max(512, tuned["d_ff"] - 128)

    final_model = NMTTrans(vocab_size=VOCAB_SIZE, **tuned)
    final_report = budget_report(model_name, target_m, count_parameters(final_model)["total"])
    del final_model
    return tuned, final_report


validated_configs = {}
param_reports = []
for m in TARGET_MILLIONS:
    name = f"{m}M"
    tuned_cfg, rpt = auto_adjust_config(name, MODEL_CONFIGS[name], target_m=m, tolerance_pct=2.5)
    validated_configs[name] = tuned_cfg
    param_reports.append(rpt)

pd.DataFrame(param_reports)
# Out:
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 10M: target=10,000,000 | actual=13,721,600 | error=+3,721,600 (+37.22%)
# 10M: target=10,000,000 | actual=13,327,616 | error=+3,327,616 (+33.28%)
# 10M: target=10,000,000 | actual=12,933,632 | error=+2,933,632 (+29.34%)
# 10M: target=10,000,000 | actual=12,539,648 | error=+2,539,648 (+25.40%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# 30M: target=30,000,000 | actual=45,809,664 | error=+15,809,664 (+52.70%)
# 30M: target=30,000,000 | actual=44,760,064 | error=+14,760,064 (+49.20%)
# 30M: target=30,000,000 | actual=43,710,464 | error=+13,710,464 (+45.70%)
# 30M: target=30,000,000 | actual=42,660,864 | error=+12,660,864 (+42.20%)
# 30M: target=30,000,000 | actual=41,611,264 | error=+11,611,264 (+38.70%)
# 30M: target=30,000,000 | actual=40,561,664 | error=+10,561,664 (+35.21%)
# 30M: target=30,000,000 | actual=39,512,064 | error=+9,512,064 (+31.71%)
# 30M: target=30,000,000 | actual=38,462,464 | error=+8,462,464 (+28.21%)
# 30M: target=30,000,000 | actual=37,412,864 | error=+7,412,864 (+24.71%)
# 30M: target=30,000,000 | actual=36,363,264 | error=+6,363,264 (+21.21%)
# 30M: target=30,000,000 | actual=35,313,664 | error=+5,313,664 (+17.71%)
# 30M: target=30,000,000 | actual=34,264,064 | error=+4,264,064 (+14.21%)
# 30M: target=30,000,000 | actual=33,214,464 | error=+3,214,464 (+10.71%)
# 50M: target=50,000,000 | actual=63,671,296 | error=+13,671,296 (+27.34%)
# 50M: target=50,000,000 | actual=62,096,896 | error=+12,096,896 (+24.19%)
# 50M: target=50,000,000 | actual=60,522,496 | error=+10,522,496 (+21.04%)
# 50M: target=50,000,000 | actual=58,948,096 | error=+8,948,096 (+17.90%)
# 50M: target=50,000,000 | actual=57,373,696 | error=+7,373,696 (+14.75%)
# 50M: target=50,000,000 | actual=55,799,296 | error=+5,799,296 (+11.60%)
# 50M: target=50,000,000 | actual=54,224,896 | error=+4,224,896 (+8.45%)
# 50M: target=50,000,000 | actual=52,650,496 | error=+2,650,496 (+5.30%)
# 50M: target=50,000,000 | actual=51,076,096 | error=+1,076,096 (+2.15%)
# 60M: target=60,000,000 | actual=89,415,680 | error=+29,415,680 (+49.03%)
# 60M: target=60,000,000 | actual=87,448,064 | error=+27,448,064 (+45.75%)
# 60M: target=60,000,000 | actual=85,480,448 | error=+25,480,448 (+42.47%)
# 60M: target=60,000,000 | actual=83,512,832 | error=+23,512,832 (+39.19%)
# 60M: target=60,000,000 | actual=81,545,216 | error=+21,545,216 (+35.91%)
# 60M: target=60,000,000 | actual=79,577,600 | error=+19,577,600 (+32.63%)
# 60M: target=60,000,000 | actual=77,609,984 | error=+17,609,984 (+29.35%)
# 60M: target=60,000,000 | actual=75,642,368 | error=+15,642,368 (+26.07%)
# 60M: target=60,000,000 | actual=73,674,752 | error=+13,674,752 (+22.79%)
# 60M: target=60,000,000 | actual=71,707,136 | error=+11,707,136 (+19.51%)
# 60M: target=60,000,000 | actual=69,739,520 | error=+9,739,520 (+16.23%)
# 60M: target=60,000,000 | actual=67,771,904 | error=+7,771,904 (+12.95%)
# 60M: target=60,000,000 | actual=65,804,288 | error=+5,804,288 (+9.67%)
#   model  target_m  target_params  actual_params  abs_error  pct_error
# 0   10M        10       10000000       12145664    2145664  21.456640
# 1   30M        30       30000000       33214464    3214464  10.714880
# 2   50M        50       50000000       51076096    1076096   2.152192
# 3   60M        60       60000000       65804288    5804288   9.673813

# %%
class NMTDataset(Dataset):
    def __init__(self, src_mmap: np.ndarray, tgt_mmap: np.ndarray, lengths: np.ndarray):
        # Memory-mapped numpy array containing source token IDs. Memory mapping avoids loading
        # the entire array into RAM, instead reading from disk as needed.
        self.src = src_mmap
        # Memory-mapped numpy array containing target token IDs.
        self.tgt = tgt_mmap
        # Array containing the true sequence lengths for each source and target sentence pair.
        self.lengths = lengths

    def __len__(self) -> int:
        # Returns the total number of sentence pairs in the dataset.
        return len(self.lengths)

    def __getitem__(self, idx: int):
        # Get the actual lengths of the source and target sequences for this specific index.
        sl, tl = int(self.lengths[idx, 0]), int(self.lengths[idx, 1])
        # Read the sequence from the memory-mapped array, copy it to memory, and convert to a PyTorch tensor.
        # We only slice up to the true sequence length (sl, tl) to ignore empty padding values.
        src = torch.from_numpy(self.src[idx, :sl].copy()).long()
        tgt = torch.from_numpy(self.tgt[idx, :tl].copy()).long()
        return src, tgt


class BucketBatchSampler(Sampler):
    def __init__(self, lengths: np.ndarray, max_tokens: int, shuffle: bool = True):
        # The maximum total number of tokens allowed in a single batch (batch_size * max_seq_length).
        self.max_tokens = max_tokens
        # Whether to randomly shuffle the order of the *batches* before each epoch.
        self.shuffle = shuffle
        # For each sentence pair, calculate the maximum length between the source and target.
        # This defines the "bounding box" or padding required for that pair.
        self.max_lens = np.maximum(lengths[:, 0], lengths[:, 1])
        # Sort the dataset indices by sequence length. Grouping similar lengths minimizes padding waste.
        self.sorted_indices = np.argsort(self.max_lens)
        # Pre-compute the exact data indices that form each batch using the lengths and token limit.
        self.batches = self._build_batches()

    def _build_batches(self):
        batches = []
        cur_batch, cur_max_len = [], 0
        # Iterate over the dataset indices, ordered from shortest to longest sequences.
        for idx in self.sorted_indices:
            # The length of the current sequence pair.
            seq_len = int(self.max_lens[idx])
            # The maximum sequence length of the batch if we decide to add this sequence.
            candidate_max = max(cur_max_len, seq_len)
            
            # Check if adding this sequence would cause the batch's total padded token count 
            # (number of sentences * max_length_in_batch) to exceed the allowed limit.
            if (len(cur_batch) + 1) * candidate_max > self.max_tokens:
                # The batch is "full". Save it to our list of batches.
                if cur_batch:
                    batches.append(cur_batch)
                # Start a new batch containing only the current sequence.
                cur_batch, cur_max_len = [int(idx)], seq_len
            else:
                # It fits! Add the index to the current batch and update the max length.
                cur_batch.append(int(idx))
                cur_max_len = candidate_max
                
        # After the loop finishes, append any remaining sequences as the final batch.
        if cur_batch:
            batches.append(cur_batch)
        return batches

    def __iter__(self):
        if self.shuffle:
            random.shuffle(self.batches)
        for batch in self.batches:
            yield batch

    def __len__(self) -> int:
        return len(self.batches)


def collate_fn(batch):
    src, tgt = zip(*batch)
    src_max = max(s.size(0) for s in src)
    tgt_max = max(t.size(0) for t in tgt)
    src_pad = torch.full((len(batch), src_max), PAD_ID, dtype=torch.long)
    tgt_pad = torch.full((len(batch), tgt_max), PAD_ID, dtype=torch.long)
    for i, (s, t) in enumerate(zip(src, tgt)):
        src_pad[i, : s.size(0)] = s
        tgt_pad[i, : t.size(0)] = t
    return src_pad, tgt_pad

# %%
cache_tag = "unigram_v1_32000"
train_src_path = CACHE_DIR / f"train_{cache_tag}_src.npy"
train_tgt_path = CACHE_DIR / f"train_{cache_tag}_tgt.npy"
train_lens_path = CACHE_DIR / f"train_{cache_tag}_lens.npy"
val_src_path = CACHE_DIR / f"val_{cache_tag}_src.npy"
val_tgt_path = CACHE_DIR / f"val_{cache_tag}_tgt.npy"
val_lens_path = CACHE_DIR / f"val_{cache_tag}_lens.npy"
cache_paths = [train_src_path, train_tgt_path, train_lens_path, val_src_path, val_tgt_path, val_lens_path]

if all(path.exists() for path in cache_paths):
    print("Cache already exists; skipping rebuild.")
else:
    import pyarrow.parquet as pq

    parquet_files = sorted(DATA_DIR.glob("train-*.parquet"))
    if not parquet_files:
        raise FileNotFoundError("No parquet shards found under the data directory.")

    total_rows = sum(pq.ParquetFile(str(path)).metadata.num_rows for path in parquet_files)
    val_size = min(4928, total_rows)
    train_rows = total_rows - val_size

    def encode_example(text):
        # Encode text to token IDs, adding Start-Of-Sequence and End-Of-Sequence tags.
        # Truncate to MAX_SEQ_LEN - 2 to leave room for BOS and EOS.
        token_ids = [BOS_ID] + sp.encode(str(text), out_type=int)[: MAX_SEQ_LEN - 2] + [EOS_ID]
        token_ids = token_ids[:MAX_SEQ_LEN]
        
        # Create a uniform row filled with PAD_ID. This standardizes the shape for on-disk storage.
        row = np.full(MAX_SEQ_LEN, PAD_ID, dtype=np.int32)
        row[:len(token_ids)] = token_ids
        
        # Return the padded row and the actual sequence length (used later to slice off padding).
        return row, len(token_ids)

    # Create memory-mapped files on disk. This allows us to write and read a massive
    # dataset matrix without requiring enough RAM to hold it all at once.
    train_src = np.lib.format.open_memmap(str(train_src_path), mode="w+", dtype=np.int32, shape=(train_rows, MAX_SEQ_LEN))
    train_tgt = np.lib.format.open_memmap(str(train_tgt_path), mode="w+", dtype=np.int32, shape=(train_rows, MAX_SEQ_LEN))
    train_lens = np.lib.format.open_memmap(str(train_lens_path), mode="w+", dtype=np.int32, shape=(train_rows, 2))
    val_src = np.lib.format.open_memmap(str(val_src_path), mode="w+", dtype=np.int32, shape=(val_size, MAX_SEQ_LEN))
    val_tgt = np.lib.format.open_memmap(str(val_tgt_path), mode="w+", dtype=np.int32, shape=(val_size, MAX_SEQ_LEN))
    val_lens = np.lib.format.open_memmap(str(val_lens_path), mode="w+", dtype=np.int32, shape=(val_size, 2))

    global_idx = 0
    train_idx = 0
    val_idx = 0

    for parquet_path in parquet_files:
        parquet_file = pq.ParquetFile(str(parquet_path))
        # Read the parquet files in chunks (batches) to remain memory efficient.
        for batch in parquet_file.iter_batches(batch_size=8192, columns=["src", "tgt"]):
            src_values = batch.column(0).to_pylist()
            tgt_values = batch.column(1).to_pylist()
            
            # Process each text pair, pad it for standard storage, and insert it into the memory-mapped array.
            for src_text, tgt_text in zip(src_values, tgt_values):
                src_row, src_len = encode_example(src_text)
                tgt_row, tgt_len = encode_example(tgt_text)
                if global_idx < train_rows:
                    train_src[train_idx] = src_row
                    train_tgt[train_idx] = tgt_row
                    train_lens[train_idx] = (src_len, tgt_len)
                    train_idx += 1
                else:
                    val_src[val_idx] = src_row
                    val_tgt[val_idx] = tgt_row
                    val_lens[val_idx] = (src_len, tgt_len)
                    val_idx += 1
                global_idx += 1

    train_src.flush()
    train_tgt.flush()
    train_lens.flush()
    val_src.flush()
    val_tgt.flush()
    val_lens.flush()

    print(f"Created cache: train={train_idx:,} | val={val_idx:,} | total={global_idx:,}")

# %%
# All parquet files are treated as training corpus.
parquet_files = sorted(DATA_DIR.glob("train-*.parquet"))
print(f"Detected parquet training files: {len(parquet_files)}")
for p in parquet_files:
    print(f"  - {p.name}")

# The val cache below is a held-out split derived from that same training corpus.
cache_tag = "unigram_v1_32000"
train_src = np.load(str(CACHE_DIR / f"train_{cache_tag}_src.npy"), mmap_mode="r")
train_tgt = np.load(str(CACHE_DIR / f"train_{cache_tag}_tgt.npy"), mmap_mode="r")
train_lens = np.load(str(CACHE_DIR / f"train_{cache_tag}_lens.npy"))
val_src = np.load(str(CACHE_DIR / f"val_{cache_tag}_src.npy"), mmap_mode="r")
val_tgt = np.load(str(CACHE_DIR / f"val_{cache_tag}_tgt.npy"), mmap_mode="r")
val_lens = np.load(str(CACHE_DIR / f"val_{cache_tag}_lens.npy"))

train_dataset = NMTDataset(train_src, train_tgt, train_lens)
val_dataset = NMTDataset(val_src, val_tgt, val_lens)

print(f"Loaded cached arrays: train={len(train_dataset):,} | val={len(val_dataset):,}")
# Out:
# Detected parquet training files: 3
#   - train-00000-of-00003.parquet
#   - train-00001-of-00003.parquet
#   - train-00002-of-00003.parquet
# Loaded cached arrays: train=4,936,998 | val=4,928

# %%
# --- Data Loading Utilities ---
def make_loaders(max_tokens: int):
    # Configures PyTorch DataLoaders using our sequence-length bucket sampler and dynamic padding collation
    workers = int(TRAINING_DEFAULTS["num_workers"])
    workers = max(0, min(workers, os.cpu_count() or 1))
    pin = DEVICE.type == "cuda"
    common_kwargs = {
        "collate_fn": collate_fn,
        "num_workers": workers,
        "pin_memory": pin,
        "persistent_workers": workers > 0,
    }
    if workers > 0:
        common_kwargs["prefetch_factor"] = int(TRAINING_DEFAULTS["prefetch_factor"])

    train_loader = DataLoader(
        train_dataset,
        batch_sampler=BucketBatchSampler(train_lens, max_tokens=max_tokens, shuffle=True),
        **common_kwargs,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_sampler=BucketBatchSampler(val_lens, max_tokens=max_tokens, shuffle=False),
        **common_kwargs,
    )
    return train_loader, val_loader


# --- Memory Management & OOM Recovery Utilities ---
def clear_runtime_memory():
    # Force Python garbage collection and empty PyTorch's pre-allocated CUDA cache, helpful post-OOM
    gc.collect()
    if DEVICE.type == "cuda":
        torch.cuda.empty_cache()


def is_oom_error(exc: RuntimeError) -> bool:
    # Helper to aggressively detect Out-of-Memory exceptions, distinguishing them from logic errors
    msg = str(exc).lower()
    return (
        "out of memory" in msg
        or "cuda error: out of memory" in msg
        or "cudnn_status_alloc_failed" in msg
    )


# --- Transformer Training Schedule Utilities ---
def make_scheduler(optimizer, warmup_steps: int):
    # Implements the standard Transformer learning rate schedule: linear warmup followed by inverse square-root decay
    def lr_lambda(step: int):
        step = max(step, 1)
        return min(step ** (-0.5), step * warmup_steps ** (-1.5)) * (warmup_steps ** 0.5)

    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)


def safe_ppl(loss_value: float) -> float:
    # Calculates perplexity safely, clamping the math limit to avoid 'inf' overflow on very high early loss
    return math.exp(min(loss_value, 20.0))


# Setup Mixed Precision (AMP) variables. bfloat16 is preferred on Ampere+ GPUs for stability, falling back to float16
AMP_DTYPE = torch.bfloat16 if DEVICE.type == "cuda" and torch.cuda.is_bf16_supported() else torch.float16


def amp_ctx():
    # Returns the precision context manager based on device capabilities
    enabled = TRAINING_DEFAULTS["use_amp"] and DEVICE.type == "cuda"
    if enabled:
        return torch.amp.autocast(device_type="cuda", dtype=AMP_DTYPE)
    return torch.amp.autocast(device_type=DEVICE.type, enabled=False)


def make_grad_scaler():
    # Creates the Gradient Scaler needed to prevent underflow specifically when using float16 mixed precision.
    enabled = TRAINING_DEFAULTS["use_amp"] and DEVICE.type == "cuda" and AMP_DTYPE == torch.float16
    try:
        return torch.amp.GradScaler(device=DEVICE.type, enabled=enabled)
    except TypeError:
        if DEVICE.type == "cuda":
            return torch.amp.GradScaler("cuda", enabled=enabled)
        return torch.amp.GradScaler(enabled=enabled)


def choose_grad_accum(base_max_tokens: int, base_grad_accum: int, current_max_tokens: int) -> int:
    # Called if the VRAM limits are exceeded. When max_tokens shrinks, this increases 
    # accumulation steps to maintain the target "global effective batch size".
    target_effective_tokens = max(1, base_max_tokens * base_grad_accum)
    adjusted = math.ceil(target_effective_tokens / max(current_max_tokens, 1))
    return max(1, min(TRAINING_DEFAULTS["max_grad_accum"], adjusted))


def build_optimizer(model):
    # Initializes standard AdamW, prioritizing the heavily optimized CUDA 'fused' execution path if supported
    kwargs = {
        "lr": TRAINING_DEFAULTS["lr"],
        "betas": (0.9, 0.98),
        "eps": 1e-9,
        "weight_decay": TRAINING_DEFAULTS["weight_decay"],
    }
    if DEVICE.type == "cuda":
        try:
            return torch.optim.AdamW(model.parameters(), fused=True, **kwargs), "fused"
        except TypeError:
            pass
    return torch.optim.AdamW(model.parameters(), **kwargs), "standard"

# %%
def train_model(
    name: str,
    model,
    train_loader,
    val_loader,
    optimizer,
    train_criterion,
    eval_criterion,
    scaler,
    scheduler,
    grad_accum: int,
    epochs: int,
):
    # Train for multiple epochs with AMP, gradient accumulation, and throughput logging.
    best_val = float("inf")
    best_epoch = 0
    start = time.time()
    total_tokens_all_epochs = 0

    for epoch in range(1, epochs + 1):
        model.train()
        total_loss = 0.0
        total_tokens = 0
        processed_samples = 0

        optimizer.zero_grad(set_to_none=True)
        t0 = time.time()
        interval_t0 = t0
        interval_tokens = 0

        if DEVICE.type == "cuda":
            torch.cuda.reset_peak_memory_stats()

        max_train_batches = min(TRAINING_DEFAULTS["max_train_batches_per_epoch"], len(train_loader))
        log_interval = max(1, max_train_batches // 10)

        for i, (src, tgt) in enumerate(train_loader, start=1):
            if i > max_train_batches:
                break

            if tgt.size(1) < 2:
                continue  # Skip empty/too-short targets.

            try:
                src = src.to(DEVICE, non_blocking=True)
                tgt = tgt.to(DEVICE, non_blocking=True)
                tgt_input, tgt_label = tgt[:, :-1], tgt[:, 1:]

                with amp_ctx():
                    logits = model(src, tgt_input)
                    # Normalize loss for gradient accumulation.
                    loss = train_criterion(logits.reshape(-1, logits.size(-1)), tgt_label.reshape(-1)) / grad_accum

                if not torch.isfinite(loss.detach()):
                    raise RuntimeError(f"Non-finite loss in {name} epoch={epoch} batch={i}")

            except RuntimeError as exc:
                if is_oom_error(exc):
                    clear_runtime_memory()
                    raise RuntimeError(f"OOM in {name} epoch={epoch} batch={i}") from exc
                raise

            try:
                scaler.scale(loss).backward()
            except RuntimeError as exc:
                if is_oom_error(exc):
                    clear_runtime_memory()
                    raise RuntimeError(f"OOM during backward in {name} epoch={epoch} batch={i}") from exc
                raise

            if i % grad_accum == 0 or i == max_train_batches:
                # Unscale, clip, and step optimizer at accumulation boundary.
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), TRAINING_DEFAULTS["grad_clip"])
                try:
                    scaler.step(optimizer)
                    scaler.update()
                    optimizer.zero_grad(set_to_none=True)
                    scheduler.step()
                except RuntimeError as exc:
                    if is_oom_error(exc):
                        clear_runtime_memory()
                        raise RuntimeError(f"OOM during optimizer step in {name} epoch={epoch} batch={i}") from exc
                    raise

            n_tokens = int((tgt_label != PAD_ID).sum().item())
            if n_tokens <= 0:
                continue

            batch_samples = src.size(0)
            total_loss += loss.item() * grad_accum * n_tokens
            total_tokens += n_tokens
            interval_tokens += n_tokens
            processed_samples += batch_samples

            if i % log_interval == 0 or i == 1 or i == max_train_batches:
                avg_loss = total_loss / max(total_tokens, 1)
                current_lr = optimizer.param_groups[0]["lr"]

                now = time.time()
                elapsed_interval = max(1e-3, now - interval_t0)
                tokens_per_sec = interval_tokens / elapsed_interval
                speed_flag = "OK" if tokens_per_sec >= TRAINING_DEFAULTS["target_tokens_per_sec"] else "LOW"

                print(
                    f"    batch {i:,}/{max_train_batches:,} | batch_size={batch_samples} | samples={processed_samples:,} | "
                    f"loss={avg_loss:.4f} | ppl={safe_ppl(avg_loss):.2f} | "
                    f"lr={current_lr:.2e} | throughput={tokens_per_sec:,.0f} tok/s ({speed_flag})"
                )

                interval_t0 = time.time()
                interval_tokens = 0

        avg_loss = total_loss / max(total_tokens, 1)
        tr_time = time.time() - t0
        epoch_tokens_per_sec = total_tokens / max(tr_time, 1e-6)

        # Validation pass to track best epoch.
        try:
            val_loss = evaluate(model, val_loader, eval_criterion)
        except RuntimeError as exc:
            if is_oom_error(exc):
                clear_runtime_memory()
                raise RuntimeError(f"OOM during validation in {name} epoch={epoch}") from exc
            raise

        train_ppl = safe_ppl(avg_loss)
        val_ppl = safe_ppl(val_loss)
        peak_mem_gb = (torch.cuda.max_memory_allocated() / 1e9) if DEVICE.type == "cuda" else 0.0

        speed_flag = "OK" if epoch_tokens_per_sec >= TRAINING_DEFAULTS["target_tokens_per_sec"] else "LOW"
        print(
            f"{name} | epoch={epoch} | train_loss={avg_loss:.4f} | train_ppl={train_ppl:.2f} | "
            f"val_loss={val_loss:.4f} | val_ppl={val_ppl:.2f} | "
            f"epoch_tps={epoch_tokens_per_sec:,.0f} ({speed_flag}) | peak_mem={peak_mem_gb:.2f} GB | epoch_time={tr_time:.1f}s"
        )

        total_tokens_all_epochs += total_tokens

        if val_loss < best_val:
            best_val = val_loss
            best_epoch = epoch

    elapsed = time.time() - start
    avg_tokens_per_sec = total_tokens_all_epochs / max(elapsed, 1e-6)
    return best_epoch, best_val, elapsed, avg_tokens_per_sec


@torch.inference_mode()
def evaluate(model, loader, criterion):
    model.eval()
    total_loss, total_tokens = 0.0, 0
    max_val_batches = min(TRAINING_DEFAULTS["max_val_batches"], len(loader))

    for i, (src, tgt) in enumerate(loader, start=1):
        if i > max_val_batches:
            break

        if tgt.size(1) < 2:
            continue

        src = src.to(DEVICE, non_blocking=True)
        tgt = tgt.to(DEVICE, non_blocking=True)
        tgt_input, tgt_label = tgt[:, :-1], tgt[:, 1:]

        with amp_ctx():
            logits = model(src, tgt_input)
            loss = criterion(logits.reshape(-1, logits.size(-1)), tgt_label.reshape(-1))

        n_tokens = int((tgt_label != PAD_ID).sum().item())
        if n_tokens <= 0:
            continue

        total_loss += loss.item() * n_tokens
        total_tokens += n_tokens

    return total_loss / max(total_tokens, 1)


@torch.inference_mode()
def greedy_decode(model, src_text, sp_model, max_len=100):
    model.eval()
    m = model._orig_mod if hasattr(model, "_orig_mod") else model

    # Tokenization happens here: raw text is converted to SentencePiece token IDs.
    src_ids = [BOS_ID] + sp_model.encode(src_text)[: MAX_SEQ_LEN - 2] + [EOS_ID]
    src_tensor = torch.tensor([src_ids], dtype=torch.long, device=DEVICE)
    src_pad_mask = src_tensor == PAD_ID

    src_emb = m.position(m.embedding(src_tensor) * m.scale)
    memory = m.encoder(src_emb, src_key_padding_mask=src_pad_mask)

    tgt_ids = [BOS_ID]
    for _ in range(max_len):
        tgt_tensor = torch.tensor([tgt_ids], dtype=torch.long, device=DEVICE)
        tgt_pad_mask = tgt_tensor == PAD_ID
        tgt_emb = m.position(m.embedding(tgt_tensor) * m.scale)
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(len(tgt_ids), device=DEVICE)
        out = m.decoder(
            tgt=tgt_emb,
            memory=memory,
            tgt_mask=tgt_mask,
            tgt_key_padding_mask=tgt_pad_mask,
            memory_key_padding_mask=src_pad_mask,
        )
        logits = m.lm_head(out[:, -1, :])
        next_id = logits.argmax(dim=-1).item()
        if next_id == EOS_ID:
            break
        tgt_ids.append(next_id)

    return sp_model.decode(tgt_ids[1:])


def run_sample_inferences(trained_model, sample_texts):
    print("\n" + "=" * 60)
    print("Sample Inferences")
    print("=" * 60)
    for src_text in sample_texts:
        translation = greedy_decode(trained_model, src_text, sp)
        print(f"\nEN: {src_text}")
        print(f"TE: {translation}")

# %%
def train_and_save_all_models():
    all_results = []  # stores final results of all models

    # Print dataset info (helps understand training scale)
    train_samples = len(train_dataset)
    val_samples = len(val_dataset)
    print("\n=== Dataset Summary Before Training ===")
    print(f"Training samples: {train_samples:,}")
    print(f"Validation samples: {val_samples:,}")
    print(f"Total samples: {train_samples + val_samples:,}")
    print(f"AMP dtype: {AMP_DTYPE}")  # precision used (important for speed)

    # Loop over different model sizes (10M, 30M, 50M, 60M)
    for target_m in TARGET_MILLIONS:
        name = f"{target_m}M"
        cfg = validated_configs[name]  # tuned config matching parameter budget

        # Batch policy → controls memory usage
        base_policy = dict(BATCH_POLICY[name])
        base_max_tokens = int(base_policy["max_tokens"])
        base_grad_accum = int(base_policy["grad_accum"])

        # Initial training settings
        max_tokens = base_max_tokens
        grad_accum = base_grad_accum
        attempts = 0  # number of retries if OOM occurs

        print("\n" + "=" * 72)
        print(f"Training {name} | cfg={cfg} | initial_policy={base_policy}")
        print("=" * 72)

        # Retry loop → handles GPU memory errors dynamically
        while True:
            # Initialize variables (helps safe cleanup on failure)
            model = None
            optimizer = None
            train_criterion = None
            eval_criterion = None
            scaler = None
            scheduler = None
            train_loader = None
            val_loader = None

            try:
                print(f"Attempt {attempts + 1}: max_tokens={max_tokens}, grad_accum={grad_accum}")

                # Create dataloaders (handles batching and padding)
                train_loader, val_loader = make_loaders(max_tokens=max_tokens)

                print(f"Samples: train={len(train_dataset):,} | val={len(val_dataset):,}")
                print(f"Batches: train={len(train_loader):,} | val={len(val_loader):,}")

                # Build model and move to device (GPU/CPU)
                model = NMTTrans(vocab_size=VOCAB_SIZE, **cfg).to(DEVICE)

                # Check parameter count → ensures model matches target size
                counts = count_parameters(model)
                budget = budget_report(name, target_m, counts["total"])

                # Optimizer (AdamW)
                optimizer, optimizer_mode = build_optimizer(model)

                # Loss functions
                train_criterion = nn.CrossEntropyLoss(
                    ignore_index=PAD_ID,
                    label_smoothing=TRAINING_DEFAULTS["label_smoothing"],  # smoother training
                )
                eval_criterion = nn.CrossEntropyLoss(
                    ignore_index=PAD_ID,
                    label_smoothing=0.0,  # exact evaluation
                )

                # Mixed precision + scheduler
                scaler = make_grad_scaler()
                scheduler = make_scheduler(optimizer, warmup_steps=TRAINING_DEFAULTS["warmup_steps"])

                # Main training loop
                best_epoch, best_val, elapsed, avg_tps = train_model(
                    name=name,
                    model=model,
                    train_loader=train_loader,
                    val_loader=val_loader,
                    optimizer=optimizer,
                    train_criterion=train_criterion,
                    eval_criterion=eval_criterion,
                    scaler=scaler,
                    scheduler=scheduler,
                    grad_accum=grad_accum,
                    epochs=TRAINING_DEFAULTS["epochs_per_model"],
                )

                # Store actual batch settings used
                effective_policy = {"max_tokens": max_tokens, "grad_accum": grad_accum}

                break  # training successful → exit retry loop

            except RuntimeError as exc:
                # Handle GPU Out-Of-Memory errors
                if not is_oom_error(exc):
                    raise

                attempts += 1
                print(f"OOM detected for {name}: {exc}")

                # Stop if too many retries
                if attempts > TRAINING_DEFAULTS["oom_retry_limit"]:
                    raise RuntimeError(
                        f"Exceeded OOM retry limit for {name}. "
                        f"Last max_tokens={max_tokens}."
                    ) from exc

                # Reduce batch size to fit memory
                next_max_tokens = max(
                    TRAINING_DEFAULTS["min_max_tokens"],
                    int(max_tokens * TRAINING_DEFAULTS["auto_batch_shrink_factor"]),
                )

                # Ensure reduction actually happens
                if next_max_tokens >= max_tokens:
                    next_max_tokens = max(TRAINING_DEFAULTS["min_max_tokens"], max_tokens - 256)

                if next_max_tokens == max_tokens:
                    raise RuntimeError(
                        f"OOM persists for {name}; cannot shrink max_tokens below {max_tokens}."
                    ) from exc

                max_tokens = next_max_tokens

                # Adjust gradient accumulation → keeps effective batch size stable
                grad_accum = choose_grad_accum(base_max_tokens, base_grad_accum, max_tokens)

                print(
                    f"Retrying {name} with reduced max_tokens={max_tokens}, "
                    f"adjusted grad_accum={grad_accum}"
                )

                # Clean memory before retry
                if model is not None:
                    del model
                if optimizer is not None:
                    del optimizer
                if train_criterion is not None:
                    del train_criterion
                if eval_criterion is not None:
                    del eval_criterion
                if scaler is not None:
                    del scaler
                if scheduler is not None:
                    del scheduler
                if train_loader is not None:
                    del train_loader
                if val_loader is not None:
                    del val_loader

                clear_runtime_memory()

        # Check if training speed meets target
        throughput_ok = avg_tps >= TRAINING_DEFAULTS["target_tokens_per_sec"]

        # Save model checkpoint + metadata
        save_path = CHECKPOINT_DIR / f"final_{target_m}m_model.pt"
        torch.save(
            {
                "model_name": name,
                "target_m": target_m,
                "config": cfg,
                "param_counts": counts,
                "budget_report": budget,
                "batch_policy": effective_policy,
                "training_defaults": TRAINING_DEFAULTS,
                "optimizer_mode": optimizer_mode,
                "amp_dtype": str(AMP_DTYPE),
                "best_epoch": best_epoch,
                "best_val_loss": best_val,
                "avg_tokens_per_sec": avg_tps,
                "target_met": throughput_ok,
                "oom_retries": attempts,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
            },
            save_path,
        )

        print(f"Saved: {save_path}")

        # Quick sample inference → sanity check for translation quality
        try:
            run_sample_inferences(model, sample_texts)
        except RuntimeError as exc:
            if is_oom_error(exc):
                clear_runtime_memory()
            else:
                raise

        # Store results for comparison
        all_results.append(
            {
                "model": name,
                "best_val_loss": best_val,
                "avg_tokens_per_sec": avg_tps,
            }
        )

        # Free memory before next model
        del model, optimizer, train_loader, val_loader
        clear_runtime_memory()

    # Convert results to DataFrame
    result_df = pd.DataFrame(all_results)

    return result_df


# Run full training pipeline
results_df = train_and_save_all_models()
results_df
# Out:
# === Dataset Summary Before Training ===
# Training samples: 4,936,998
# Validation samples: 4,928
# Total samples: 4,941,926
# AMP dtype: torch.bfloat16
#
# ========================================================================
# Training 10M | cfg={'d_model': 256, 'nhead': 4, 'num_enc_layers': 3, 'num_dec_layers': 3, 'd_ff': 512, 'dropout': 0.1} | initial_policy={'max_tokens': 9000, 'grad_accum': 2}
# ========================================================================
# Attempt 1: max_tokens=9000, grad_accum=2
# Samples: train=4,936,998 | val=4,928
# Batches: train=8,448 | val=10
# Initial LR: 5.00e-04 | grad_accum=2
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 10M: target=10,000,000 | actual=12,145,664 | error=+2,145,664 (+21.46%)
# Optimizer mode: fused
# /home/user35/project/.venv/lib/python3.11/site-packages/torch/nn/modules/activation.py:1336: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   key_padding_mask = F._canonical_mask(
#     batch 1/7,000 | batch_size=529 | samples=529 | loss=10.4388 | ppl=34159.05 | lr=1.67e-07 | throughput=14,935 tok/s (LOW)
#     batch 700/7,000 | batch_size=257 | samples=430,023 | loss=8.7100 | ppl=6063.26 | lr=5.83e-05 | throughput=120,622 tok/s (OK)
#     batch 1,400/7,000 | batch_size=375 | samples=834,368 | loss=8.2154 | ppl=3697.39 | lr=1.17e-04 | throughput=121,601 tok/s (OK)
#     batch 2,100/7,000 | batch_size=264 | samples=1,254,383 | loss=7.8375 | ppl=2533.79 | lr=1.75e-04 | throughput=120,938 tok/s (OK)
#     batch 2,800/7,000 | batch_size=360 | samples=1,672,625 | loss=7.5065 | ppl=1819.89 | lr=2.33e-04 | throughput=121,072 tok/s (OK)
#     batch 3,500/7,000 | batch_size=264 | samples=2,070,754 | loss=7.2328 | ppl=1384.05 | lr=2.92e-04 | throughput=121,687 tok/s (OK)
#     batch 4,200/7,000 | batch_size=166 | samples=2,480,914 | loss=6.9985 | ppl=1094.94 | lr=3.50e-04 | throughput=121,713 tok/s (OK)
#     batch 4,900/7,000 | batch_size=1125 | samples=2,887,193 | loss=6.7992 | ppl=897.15 | lr=4.08e-04 | throughput=121,439 tok/s (OK)
#     batch 5,600/7,000 | batch_size=818 | samples=3,303,243 | loss=6.6207 | ppl=750.44 | lr=4.67e-04 | throughput=121,007 tok/s (OK)
#     batch 6,300/7,000 | batch_size=900 | samples=3,691,908 | loss=6.4699 | ppl=645.43 | lr=4.88e-04 | throughput=121,146 tok/s (OK)
#     batch 7,000/7,000 | batch_size=600 | samples=4,096,464 | loss=6.3334 | ppl=563.07 | lr=4.63e-04 | throughput=121,401 tok/s (OK)
# 10M | epoch=1 | train_loss=6.3334 | train_ppl=563.07 | val_loss=3.8641 | val_ppl=47.66 | epoch_tps=121,138 (OK) | peak_mem=5.74 GB | epoch_time=425.3s
#     batch 1/7,000 | batch_size=562 | samples=562 | loss=4.8849 | ppl=132.27 | lr=4.63e-04 | throughput=86,199 tok/s (LOW)
#     batch 700/7,000 | batch_size=346 | samples=414,085 | loss=4.9617 | ppl=142.84 | lr=4.41e-04 | throughput=120,999 tok/s (OK)
#     batch 1,400/7,000 | batch_size=1500 | samples=809,799 | loss=4.9463 | ppl=140.65 | lr=4.23e-04 | throughput=121,515 tok/s (OK)
#     batch 2,100/7,000 | batch_size=529 | samples=1,228,354 | loss=4.9068 | ppl=135.20 | lr=4.06e-04 | throughput=121,827 tok/s (OK)
#     batch 2,800/7,000 | batch_size=290 | samples=1,623,987 | loss=4.8826 | ppl=131.97 | lr=3.91e-04 | throughput=121,471 tok/s (OK)
#     batch 3,500/7,000 | batch_size=346 | samples=2,038,034 | loss=4.8511 | ppl=127.88 | lr=3.78e-04 | throughput=121,851 tok/s (OK)
#     batch 4,200/7,000 | batch_size=290 | samples=2,434,748 | loss=4.8274 | ppl=124.89 | lr=3.66e-04 | throughput=122,077 tok/s (OK)
#     batch 4,900/7,000 | batch_size=1000 | samples=2,843,062 | loss=4.8043 | ppl=122.03 | lr=3.55e-04 | throughput=121,768 tok/s (OK)
#     batch 5,600/7,000 | batch_size=360 | samples=3,259,657 | loss=4.7791 | ppl=118.99 | lr=3.45e-04 | throughput=121,819 tok/s (OK)
#     batch 6,300/7,000 | batch_size=290 | samples=3,658,614 | loss=4.7593 | ppl=116.67 | lr=3.36e-04 | throughput=121,474 tok/s (OK)
#     batch 7,000/7,000 | batch_size=250 | samples=4,094,331 | loss=4.7347 | ppl=113.83 | lr=3.27e-04 | throughput=121,441 tok/s (OK)
# 10M | epoch=2 | train_loss=4.7347 | train_ppl=113.83 | val_loss=3.2666 | val_ppl=26.22 | epoch_tps=121,616 (OK) | peak_mem=5.75 GB | epoch_time=423.6s
#     batch 1/7,000 | batch_size=642 | samples=642 | loss=4.2471 | ppl=69.90 | lr=3.27e-04 | throughput=86,766 tok/s (LOW)
#     batch 700/7,000 | batch_size=1125 | samples=407,632 | loss=4.4897 | ppl=89.09 | lr=3.19e-04 | throughput=121,433 tok/s (OK)
#     batch 1,400/7,000 | batch_size=195 | samples=827,939 | loss=4.4803 | ppl=88.26 | lr=3.12e-04 | throughput=121,421 tok/s (OK)
#     batch 2,100/7,000 | batch_size=375 | samples=1,246,961 | loss=4.4704 | ppl=87.39 | lr=3.05e-04 | throughput=121,635 tok/s (OK)
#     batch 2,800/7,000 | batch_size=236 | samples=1,667,684 | loss=4.4598 | ppl=86.47 | lr=2.99e-04 | throughput=121,147 tok/s (OK)
#     batch 3,500/7,000 | batch_size=473 | samples=2,082,184 | loss=4.4502 | ppl=85.64 | lr=2.93e-04 | throughput=121,404 tok/s (OK)
#     batch 4,200/7,000 | batch_size=1285 | samples=2,485,230 | loss=4.4459 | ppl=85.28 | lr=2.87e-04 | throughput=121,707 tok/s (OK)
#     batch 4,900/7,000 | batch_size=692 | samples=2,891,193 | loss=4.4409 | ppl=84.85 | lr=2.82e-04 | throughput=121,597 tok/s (OK)
#     batch 5,600/7,000 | batch_size=1000 | samples=3,286,369 | loss=4.4369 | ppl=84.51 | lr=2.77e-04 | throughput=121,947 tok/s (OK)
#     batch 6,300/7,000 | batch_size=409 | samples=3,703,796 | loss=4.4278 | ppl=83.75 | lr=2.72e-04 | throughput=121,366 tok/s (OK)
#     batch 7,000/7,000 | batch_size=290 | samples=4,107,344 | loss=4.4214 | ppl=83.21 | lr=2.67e-04 | throughput=122,519 tok/s (OK)
# 10M | epoch=3 | train_loss=4.4214 | train_ppl=83.21 | val_loss=3.0492 | val_ppl=21.10 | epoch_tps=121,609 (OK) | peak_mem=5.75 GB | epoch_time=423.7s
#     batch 1/7,000 | batch_size=428 | samples=428 | loss=4.4434 | ppl=85.07 | lr=2.67e-04 | throughput=102,802 tok/s (OK)
#     batch 700/7,000 | batch_size=473 | samples=410,217 | loss=4.3158 | ppl=74.87 | lr=2.63e-04 | throughput=120,899 tok/s (OK)
#     batch 1,400/7,000 | batch_size=1800 | samples=816,252 | loss=4.3180 | ppl=75.04 | lr=2.59e-04 | throughput=121,230 tok/s (OK)
#     batch 2,100/7,000 | batch_size=1285 | samples=1,240,953 | loss=4.3106 | ppl=74.49 | lr=2.55e-04 | throughput=121,404 tok/s (OK)
#     batch 2,800/7,000 | batch_size=1500 | samples=1,662,304 | loss=4.3052 | ppl=74.08 | lr=2.51e-04 | throughput=121,439 tok/s (OK)
#     batch 3,500/7,000 | batch_size=818 | samples=2,067,816 | loss=4.3048 | ppl=74.05 | lr=2.47e-04 | throughput=121,485 tok/s (OK)
#     batch 4,200/7,000 | batch_size=529 | samples=2,452,840 | loss=4.3077 | ppl=74.27 | lr=2.44e-04 | throughput=122,024 tok/s (OK)
#     batch 4,900/7,000 | batch_size=219 | samples=2,858,955 | loss=4.3044 | ppl=74.03 | lr=2.41e-04 | throughput=121,469 tok/s (OK)
#     batch 5,600/7,000 | batch_size=642 | samples=3,270,460 | loss=4.3006 | ppl=73.75 | lr=2.37e-04 | throughput=121,915 tok/s (OK)
#     batch 6,300/7,000 | batch_size=300 | samples=3,687,857 | loss=4.2965 | ppl=73.44 | lr=2.34e-04 | throughput=121,237 tok/s (OK)
#     batch 7,000/7,000 | batch_size=281 | samples=4,088,751 | loss=4.2949 | ppl=73.32 | lr=2.31e-04 | throughput=121,474 tok/s (OK)
# 10M | epoch=4 | train_loss=4.2949 | train_ppl=73.32 | val_loss=2.9496 | val_ppl=19.10 | epoch_tps=121,453 (OK) | peak_mem=5.75 GB | epoch_time=424.2s
#     batch 1/7,000 | batch_size=1285 | samples=1,285 | loss=3.5761 | ppl=35.73 | lr=2.31e-04 | throughput=62,745 tok/s (LOW)
#     batch 700/7,000 | batch_size=1125 | samples=398,929 | loss=4.2398 | ppl=69.39 | lr=2.29e-04 | throughput=122,385 tok/s (OK)
#     batch 1,400/7,000 | batch_size=500 | samples=809,531 | loss=4.2353 | ppl=69.08 | lr=2.26e-04 | throughput=122,053 tok/s (OK)
#     batch 2,100/7,000 | batch_size=818 | samples=1,219,698 | loss=4.2362 | ppl=69.14 | lr=2.23e-04 | throughput=121,786 tok/s (OK)
#     batch 2,800/7,000 | batch_size=450 | samples=1,610,241 | loss=4.2403 | ppl=69.43 | lr=2.21e-04 | throughput=121,837 tok/s (OK)
#     batch 3,500/7,000 | batch_size=562 | samples=2,024,952 | loss=4.2354 | ppl=69.09 | lr=2.18e-04 | throughput=121,369 tok/s (OK)
#     batch 4,200/7,000 | batch_size=642 | samples=2,451,172 | loss=4.2290 | ppl=68.65 | lr=2.16e-04 | throughput=121,076 tok/s (OK)
#     batch 4,900/7,000 | batch_size=290 | samples=2,867,371 | loss=4.2261 | ppl=68.45 | lr=2.14e-04 | throughput=121,137 tok/s (OK)
#     batch 5,600/7,000 | batch_size=562 | samples=3,274,333 | loss=4.2250 | ppl=68.38 | lr=2.11e-04 | throughput=122,605 tok/s (OK)
#     batch 6,300/7,000 | batch_size=750 | samples=3,662,820 | loss=4.2268 | ppl=68.49 | lr=2.09e-04 | throughput=121,657 tok/s (OK)
#     batch 7,000/7,000 | batch_size=750 | samples=4,081,112 | loss=4.2227 | ppl=68.22 | lr=2.07e-04 | throughput=122,183 tok/s (OK)
# 10M | epoch=5 | train_loss=4.2227 | train_ppl=68.22 | val_loss=2.8944 | val_ppl=18.07 | epoch_tps=121,790 (OK) | peak_mem=5.75 GB | epoch_time=423.0s
#     batch 1/7,000 | batch_size=375 | samples=375 | loss=4.3710 | ppl=79.12 | lr=2.07e-04 | throughput=81,488 tok/s (LOW)
#     batch 700/7,000 | batch_size=529 | samples=388,862 | loss=4.1959 | ppl=66.42 | lr=2.05e-04 | throughput=121,854 tok/s (OK)
#     batch 1,400/7,000 | batch_size=1285 | samples=808,271 | loss=4.1798 | ppl=65.35 | lr=2.03e-04 | throughput=121,975 tok/s (OK)
#     batch 2,100/7,000 | batch_size=600 | samples=1,221,325 | loss=4.1788 | ppl=65.29 | lr=2.01e-04 | throughput=121,254 tok/s (OK)
#     batch 2,800/7,000 | batch_size=1000 | samples=1,635,798 | loss=4.1770 | ppl=65.17 | lr=1.99e-04 | throughput=121,373 tok/s (OK)
#     batch 3,500/7,000 | batch_size=692 | samples=2,044,881 | loss=4.1753 | ppl=65.06 | lr=1.97e-04 | throughput=121,927 tok/s (OK)
#     batch 4,200/7,000 | batch_size=529 | samples=2,447,954 | loss=4.1762 | ppl=65.12 | lr=1.96e-04 | throughput=121,369 tok/s (OK)
#     batch 4,900/7,000 | batch_size=147 | samples=2,851,859 | loss=4.1770 | ppl=65.17 | lr=1.94e-04 | throughput=121,865 tok/s (OK)
#     batch 5,600/7,000 | batch_size=818 | samples=3,247,464 | loss=4.1779 | ppl=65.23 | lr=1.92e-04 | throughput=122,078 tok/s (OK)
#     batch 6,300/7,000 | batch_size=1125 | samples=3,650,323 | loss=4.1778 | ppl=65.22 | lr=1.91e-04 | throughput=121,377 tok/s (OK)
#     batch 7,000/7,000 | batch_size=333 | samples=4,076,670 | loss=4.1743 | ppl=64.99 | lr=1.89e-04 | throughput=121,269 tok/s (OK)
# 10M | epoch=6 | train_loss=4.1743 | train_ppl=64.99 | val_loss=2.8581 | val_ppl=17.43 | epoch_tps=121,624 (OK) | peak_mem=5.75 GB | epoch_time=423.6s
#     batch 1/7,000 | batch_size=1125 | samples=1,125 | loss=3.7025 | ppl=40.55 | lr=1.89e-04 | throughput=64,419 tok/s (LOW)
#     batch 700/7,000 | batch_size=1285 | samples=408,243 | loss=4.1349 | ppl=62.49 | lr=1.87e-04 | throughput=122,137 tok/s (OK)
#     batch 1,400/7,000 | batch_size=900 | samples=816,506 | loss=4.1360 | ppl=62.55 | lr=1.86e-04 | throughput=121,948 tok/s (OK)
#     batch 2,100/7,000 | batch_size=257 | samples=1,215,227 | loss=4.1442 | ppl=63.07 | lr=1.84e-04 | throughput=121,815 tok/s (OK)
#     batch 2,800/7,000 | batch_size=300 | samples=1,604,984 | loss=4.1501 | ppl=63.44 | lr=1.83e-04 | throughput=122,318 tok/s (OK)
#     batch 3,500/7,000 | batch_size=818 | samples=2,033,919 | loss=4.1431 | ppl=63.00 | lr=1.82e-04 | throughput=121,481 tok/s (OK)
#     batch 4,200/7,000 | batch_size=818 | samples=2,450,450 | loss=4.1398 | ppl=62.79 | lr=1.80e-04 | throughput=121,823 tok/s (OK)
#     batch 4,900/7,000 | batch_size=375 | samples=2,860,470 | loss=4.1396 | ppl=62.78 | lr=1.79e-04 | throughput=122,317 tok/s (OK)
#     batch 5,600/7,000 | batch_size=243 | samples=3,276,633 | loss=4.1388 | ppl=62.73 | lr=1.78e-04 | throughput=122,047 tok/s (OK)
#     batch 6,300/7,000 | batch_size=473 | samples=3,681,589 | loss=4.1388 | ppl=62.73 | lr=1.76e-04 | throughput=122,289 tok/s (OK)
#     batch 7,000/7,000 | batch_size=692 | samples=4,089,934 | loss=4.1388 | ppl=62.73 | lr=1.75e-04 | throughput=122,190 tok/s (OK)
# 10M | epoch=7 | train_loss=4.1388 | train_ppl=62.73 | val_loss=2.8239 | val_ppl=16.84 | epoch_tps=122,020 (OK) | peak_mem=5.75 GB | epoch_time=422.2s
#     batch 1/7,000 | batch_size=818 | samples=818 | loss=3.8709 | ppl=47.99 | lr=1.75e-04 | throughput=86,532 tok/s (LOW)
#     batch 700/7,000 | batch_size=1500 | samples=390,347 | loss=4.1340 | ppl=62.42 | lr=1.74e-04 | throughput=121,920 tok/s (OK)
#     batch 1,400/7,000 | batch_size=272 | samples=800,237 | loss=4.1225 | ppl=61.71 | lr=1.73e-04 | throughput=121,598 tok/s (OK)
#     batch 2,100/7,000 | batch_size=346 | samples=1,225,168 | loss=4.1137 | ppl=61.17 | lr=1.71e-04 | throughput=121,764 tok/s (OK)
#     batch 2,800/7,000 | batch_size=818 | samples=1,620,467 | loss=4.1188 | ppl=61.48 | lr=1.70e-04 | throughput=122,204 tok/s (OK)
#     batch 3,500/7,000 | batch_size=1125 | samples=2,029,370 | loss=4.1178 | ppl=61.42 | lr=1.69e-04 | throughput=121,965 tok/s (OK)
#     batch 4,200/7,000 | batch_size=409 | samples=2,435,420 | loss=4.1173 | ppl=61.40 | lr=1.68e-04 | throughput=122,086 tok/s (OK)
#     batch 4,900/7,000 | batch_size=818 | samples=2,845,209 | loss=4.1174 | ppl=61.40 | lr=1.67e-04 | throughput=121,242 tok/s (OK)
#     batch 5,600/7,000 | batch_size=157 | samples=3,261,037 | loss=4.1147 | ppl=61.23 | lr=1.66e-04 | throughput=122,818 tok/s (OK)
#     batch 6,300/7,000 | batch_size=473 | samples=3,679,140 | loss=4.1131 | ppl=61.13 | lr=1.65e-04 | throughput=122,934 tok/s (OK)
#     batch 7,000/7,000 | batch_size=1285 | samples=4,088,727 | loss=4.1128 | ppl=61.12 | lr=1.64e-04 | throughput=122,027 tok/s (OK)
# 10M | epoch=8 | train_loss=4.1128 | train_ppl=61.12 | val_loss=2.8075 | val_ppl=16.57 | epoch_tps=122,046 (OK) | peak_mem=5.75 GB | epoch_time=422.2s
#     batch 1/7,000 | batch_size=818 | samples=818 | loss=3.8690 | ppl=47.89 | lr=1.64e-04 | throughput=72,141 tok/s (LOW)
#     batch 700/7,000 | batch_size=1000 | samples=422,832 | loss=4.0685 | ppl=58.47 | lr=1.63e-04 | throughput=122,195 tok/s (OK)
#     batch 1,400/7,000 | batch_size=250 | samples=833,127 | loss=4.0803 | ppl=59.16 | lr=1.62e-04 | throughput=122,307 tok/s (OK)
#     batch 2,100/7,000 | batch_size=391 | samples=1,241,903 | loss=4.0835 | ppl=59.35 | lr=1.61e-04 | throughput=122,891 tok/s (OK)
#     batch 2,800/7,000 | batch_size=272 | samples=1,665,545 | loss=4.0828 | ppl=59.31 | lr=1.60e-04 | throughput=121,979 tok/s (OK)
#     batch 3,500/7,000 | batch_size=428 | samples=2,068,649 | loss=4.0869 | ppl=59.55 | lr=1.59e-04 | throughput=122,625 tok/s (OK)
#     batch 4,200/7,000 | batch_size=219 | samples=2,469,333 | loss=4.0897 | ppl=59.72 | lr=1.58e-04 | throughput=122,868 tok/s (OK)
#     batch 4,900/7,000 | batch_size=230 | samples=2,880,635 | loss=4.0905 | ppl=59.77 | lr=1.57e-04 | throughput=121,824 tok/s (OK)
#     batch 5,600/7,000 | batch_size=1125 | samples=3,286,303 | loss=4.0910 | ppl=59.80 | lr=1.56e-04 | throughput=122,411 tok/s (OK)
#     batch 6,300/7,000 | batch_size=750 | samples=3,688,147 | loss=4.0930 | ppl=59.92 | lr=1.55e-04 | throughput=121,636 tok/s (OK)
#     batch 7,000/7,000 | batch_size=1285 | samples=4,090,635 | loss=4.0933 | ppl=59.94 | lr=1.54e-04 | throughput=122,392 tok/s (OK)
# 10M | epoch=9 | train_loss=4.0933 | train_ppl=59.94 | val_loss=2.7844 | val_ppl=16.19 | epoch_tps=122,299 (OK) | peak_mem=5.75 GB | epoch_time=421.2s
#     batch 1/7,000 | batch_size=900 | samples=900 | loss=3.8466 | ppl=46.83 | lr=1.54e-04 | throughput=76,302 tok/s (LOW)
#     batch 700/7,000 | batch_size=900 | samples=421,584 | loss=4.0508 | ppl=57.44 | lr=1.53e-04 | throughput=122,082 tok/s (OK)
#     batch 1,400/7,000 | batch_size=1000 | samples=835,350 | loss=4.0593 | ppl=57.93 | lr=1.53e-04 | throughput=121,828 tok/s (OK)
#     batch 2,100/7,000 | batch_size=692 | samples=1,228,452 | loss=4.0683 | ppl=58.46 | lr=1.52e-04 | throughput=122,439 tok/s (OK)
#     batch 2,800/7,000 | batch_size=900 | samples=1,632,204 | loss=4.0705 | ppl=58.59 | lr=1.51e-04 | throughput=122,515 tok/s (OK)
#     batch 3,500/7,000 | batch_size=281 | samples=2,054,404 | loss=4.0683 | ppl=58.46 | lr=1.50e-04 | throughput=122,097 tok/s (OK)
#     batch 4,200/7,000 | batch_size=750 | samples=2,458,375 | loss=4.0709 | ppl=58.61 | lr=1.49e-04 | throughput=122,340 tok/s (OK)
#     batch 4,900/7,000 | batch_size=243 | samples=2,882,113 | loss=4.0696 | ppl=58.53 | lr=1.49e-04 | throughput=122,439 tok/s (OK)
#     batch 5,600/7,000 | batch_size=183 | samples=3,297,411 | loss=4.0692 | ppl=58.51 | lr=1.48e-04 | throughput=122,470 tok/s (OK)
#     batch 6,300/7,000 | batch_size=750 | samples=3,702,018 | loss=4.0706 | ppl=58.59 | lr=1.47e-04 | throughput=121,835 tok/s (OK)
#     batch 7,000/7,000 | batch_size=818 | samples=4,108,935 | loss=4.0712 | ppl=58.63 | lr=1.46e-04 | throughput=121,683 tok/s (OK)
# 10M | epoch=10 | train_loss=4.0712 | train_ppl=58.63 | val_loss=2.7670 | val_ppl=15.91 | epoch_tps=122,161 (OK) | peak_mem=5.74 GB | epoch_time=421.7s
#     batch 1/7,000 | batch_size=900 | samples=900 | loss=3.8792 | ppl=48.39 | lr=1.46e-04 | throughput=94,332 tok/s (LOW)
#     batch 700/7,000 | batch_size=391 | samples=411,872 | loss=4.0479 | ppl=57.28 | lr=1.46e-04 | throughput=121,968 tok/s (OK)
#     batch 1,400/7,000 | batch_size=1000 | samples=812,899 | loss=4.0597 | ppl=57.95 | lr=1.45e-04 | throughput=122,044 tok/s (OK)
#     batch 2,100/7,000 | batch_size=375 | samples=1,218,019 | loss=4.0609 | ppl=58.02 | lr=1.44e-04 | throughput=122,160 tok/s (OK)
#     batch 2,800/7,000 | batch_size=281 | samples=1,641,471 | loss=4.0561 | ppl=57.75 | lr=1.44e-04 | throughput=121,874 tok/s (OK)
#     batch 3,500/7,000 | batch_size=692 | samples=2,038,488 | loss=4.0598 | ppl=57.96 | lr=1.43e-04 | throughput=121,790 tok/s (OK)
#     batch 4,200/7,000 | batch_size=900 | samples=2,446,513 | loss=4.0601 | ppl=57.98 | lr=1.42e-04 | throughput=122,328 tok/s (OK)
#     batch 4,900/7,000 | batch_size=600 | samples=2,847,093 | loss=4.0624 | ppl=58.11 | lr=1.42e-04 | throughput=122,565 tok/s (OK)
#     batch 5,600/7,000 | batch_size=391 | samples=3,257,603 | loss=4.0617 | ppl=58.07 | lr=1.41e-04 | throughput=121,965 tok/s (OK)
#     batch 6,300/7,000 | batch_size=321 | samples=3,673,324 | loss=4.0610 | ppl=58.03 | lr=1.40e-04 | throughput=122,240 tok/s (OK)
#     batch 7,000/7,000 | batch_size=346 | samples=4,085,158 | loss=4.0610 | ppl=58.03 | lr=1.40e-04 | throughput=122,670 tok/s (OK)
# 10M | epoch=11 | train_loss=4.0610 | train_ppl=58.03 | val_loss=2.7496 | val_ppl=15.64 | epoch_tps=122,154 (OK) | peak_mem=5.75 GB | epoch_time=421.7s
#     batch 1/7,000 | batch_size=473 | samples=473 | loss=4.1292 | ppl=62.13 | lr=1.40e-04 | throughput=106,880 tok/s (OK)
#     batch 700/7,000 | batch_size=692 | samples=423,696 | loss=4.0258 | ppl=56.03 | lr=1.39e-04 | throughput=121,644 tok/s (OK)
#     batch 1,400/7,000 | batch_size=360 | samples=817,494 | loss=4.0488 | ppl=57.33 | lr=1.38e-04 | throughput=121,234 tok/s (OK)
#     batch 2,100/7,000 | batch_size=642 | samples=1,236,905 | loss=4.0442 | ppl=57.07 | lr=1.38e-04 | throughput=121,817 tok/s (OK)
#     batch 2,800/7,000 | batch_size=1125 | samples=1,650,758 | loss=4.0435 | ppl=57.02 | lr=1.37e-04 | throughput=121,829 tok/s (OK)
#     batch 3,500/7,000 | batch_size=183 | samples=2,062,297 | loss=4.0448 | ppl=57.10 | lr=1.37e-04 | throughput=122,586 tok/s (OK)
#     batch 4,200/7,000 | batch_size=642 | samples=2,463,199 | loss=4.0460 | ppl=57.17 | lr=1.36e-04 | throughput=122,456 tok/s (OK)
#     batch 4,900/7,000 | batch_size=642 | samples=2,863,280 | loss=4.0473 | ppl=57.24 | lr=1.35e-04 | throughput=122,420 tok/s (OK)
#     batch 5,600/7,000 | batch_size=272 | samples=3,276,977 | loss=4.0466 | ppl=57.20 | lr=1.35e-04 | throughput=122,226 tok/s (OK)
#     batch 6,300/7,000 | batch_size=200 | samples=3,702,575 | loss=4.0447 | ppl=57.10 | lr=1.34e-04 | throughput=122,184 tok/s (OK)
#     batch 7,000/7,000 | batch_size=236 | samples=4,097,180 | loss=4.0469 | ppl=57.22 | lr=1.34e-04 | throughput=122,727 tok/s (OK)
# 10M | epoch=12 | train_loss=4.0469 | train_ppl=57.22 | val_loss=2.7405 | val_ppl=15.49 | epoch_tps=122,108 (OK) | peak_mem=5.75 GB | epoch_time=421.9s
#     batch 1/7,000 | batch_size=1000 | samples=1,000 | loss=3.6885 | ppl=39.99 | lr=1.34e-04 | throughput=77,002 tok/s (LOW)
#     batch 700/7,000 | batch_size=818 | samples=414,658 | loss=4.0182 | ppl=55.60 | lr=1.33e-04 | throughput=122,294 tok/s (OK)
#     batch 1,400/7,000 | batch_size=250 | samples=812,727 | loss=4.0307 | ppl=56.30 | lr=1.33e-04 | throughput=122,201 tok/s (OK)
#     batch 2,100/7,000 | batch_size=250 | samples=1,227,394 | loss=4.0297 | ppl=56.24 | lr=1.32e-04 | throughput=122,773 tok/s (OK)
#     batch 2,800/7,000 | batch_size=600 | samples=1,644,922 | loss=4.0303 | ppl=56.28 | lr=1.31e-04 | throughput=122,037 tok/s (OK)
#     batch 3,500/7,000 | batch_size=1500 | samples=2,053,744 | loss=4.0326 | ppl=56.41 | lr=1.31e-04 | throughput=122,154 tok/s (OK)
#     batch 4,200/7,000 | batch_size=692 | samples=2,463,492 | loss=4.0332 | ppl=56.44 | lr=1.30e-04 | throughput=122,864 tok/s (OK)
#     batch 4,900/7,000 | batch_size=818 | samples=2,879,287 | loss=4.0332 | ppl=56.44 | lr=1.30e-04 | throughput=122,174 tok/s (OK)
#     batch 5,600/7,000 | batch_size=818 | samples=3,287,700 | loss=4.0340 | ppl=56.49 | lr=1.29e-04 | throughput=121,802 tok/s (OK)
#     batch 6,300/7,000 | batch_size=375 | samples=3,688,585 | loss=4.0355 | ppl=56.57 | lr=1.29e-04 | throughput=123,470 tok/s (OK)
#     batch 7,000/7,000 | batch_size=500 | samples=4,094,609 | loss=4.0366 | ppl=56.63 | lr=1.28e-04 | throughput=121,854 tok/s (OK)
# 10M | epoch=13 | train_loss=4.0366 | train_ppl=56.63 | val_loss=2.7304 | val_ppl=15.34 | epoch_tps=122,349 (OK) | peak_mem=5.75 GB | epoch_time=421.1s
#     batch 1/7,000 | batch_size=600 | samples=600 | loss=3.9824 | ppl=53.65 | lr=1.28e-04 | throughput=93,019 tok/s (LOW)
#     batch 700/7,000 | batch_size=900 | samples=394,806 | loss=4.0370 | ppl=56.66 | lr=1.28e-04 | throughput=122,300 tok/s (OK)
#     batch 1,400/7,000 | batch_size=450 | samples=802,622 | loss=4.0276 | ppl=56.13 | lr=1.27e-04 | throughput=122,900 tok/s (OK)
#     batch 2,100/7,000 | batch_size=500 | samples=1,217,082 | loss=4.0256 | ppl=56.01 | lr=1.27e-04 | throughput=122,425 tok/s (OK)
#     batch 2,800/7,000 | batch_size=391 | samples=1,636,603 | loss=4.0235 | ppl=55.90 | lr=1.26e-04 | throughput=122,351 tok/s (OK)
#     batch 3,500/7,000 | batch_size=818 | samples=2,032,939 | loss=4.0280 | ppl=56.15 | lr=1.26e-04 | throughput=122,665 tok/s (OK)
#     batch 4,200/7,000 | batch_size=187 | samples=2,435,528 | loss=4.0291 | ppl=56.21 | lr=1.26e-04 | throughput=122,135 tok/s (OK)
#     batch 4,900/7,000 | batch_size=818 | samples=2,858,313 | loss=4.0264 | ppl=56.06 | lr=1.25e-04 | throughput=122,296 tok/s (OK)
#     batch 5,600/7,000 | batch_size=600 | samples=3,265,538 | loss=4.0270 | ppl=56.09 | lr=1.25e-04 | throughput=122,177 tok/s (OK)
#     batch 6,300/7,000 | batch_size=818 | samples=3,676,322 | loss=4.0277 | ppl=56.13 | lr=1.24e-04 | throughput=121,876 tok/s (OK)
#     batch 7,000/7,000 | batch_size=236 | samples=4,090,808 | loss=4.0276 | ppl=56.13 | lr=1.24e-04 | throughput=122,741 tok/s (OK)
# 10M | epoch=14 | train_loss=4.0276 | train_ppl=56.13 | val_loss=2.7184 | val_ppl=15.16 | epoch_tps=122,380 (OK) | peak_mem=5.75 GB | epoch_time=421.0s
#     batch 1/7,000 | batch_size=300 | samples=300 | loss=4.1897 | ppl=66.00 | lr=1.24e-04 | throughput=110,805 tok/s (OK)
#     batch 700/7,000 | batch_size=333 | samples=409,837 | loss=4.0032 | ppl=54.78 | lr=1.23e-04 | throughput=121,669 tok/s (OK)
#     batch 1,400/7,000 | batch_size=1500 | samples=810,189 | loss=4.0127 | ppl=55.30 | lr=1.23e-04 | throughput=122,953 tok/s (OK)
#     batch 2,100/7,000 | batch_size=600 | samples=1,211,760 | loss=4.0178 | ppl=55.58 | lr=1.22e-04 | throughput=121,932 tok/s (OK)
#     batch 2,800/7,000 | batch_size=1000 | samples=1,633,432 | loss=4.0135 | ppl=55.34 | lr=1.22e-04 | throughput=122,487 tok/s (OK)
#     batch 3,500/7,000 | batch_size=1000 | samples=2,050,170 | loss=4.0142 | ppl=55.38 | lr=1.22e-04 | throughput=122,516 tok/s (OK)
#     batch 4,200/7,000 | batch_size=321 | samples=2,463,146 | loss=4.0148 | ppl=55.41 | lr=1.21e-04 | throughput=121,787 tok/s (OK)
#     batch 4,900/7,000 | batch_size=500 | samples=2,876,609 | loss=4.0141 | ppl=55.37 | lr=1.21e-04 | throughput=122,593 tok/s (OK)
#     batch 5,600/7,000 | batch_size=1000 | samples=3,302,432 | loss=4.0128 | ppl=55.30 | lr=1.20e-04 | throughput=122,361 tok/s (OK)
#     batch 6,300/7,000 | batch_size=562 | samples=3,691,359 | loss=4.0165 | ppl=55.51 | lr=1.20e-04 | throughput=122,567 tok/s (OK)
#     batch 7,000/7,000 | batch_size=642 | samples=4,100,033 | loss=4.0175 | ppl=55.56 | lr=1.20e-04 | throughput=122,599 tok/s (OK)
# 10M | epoch=15 | train_loss=4.0175 | train_ppl=55.56 | val_loss=2.7137 | val_ppl=15.08 | epoch_tps=122,343 (OK) | peak_mem=5.75 GB | epoch_time=421.2s
#     batch 1/7,000 | batch_size=375 | samples=375 | loss=4.1737 | ppl=64.96 | lr=1.20e-04 | throughput=101,302 tok/s (OK)
#     batch 700/7,000 | batch_size=219 | samples=403,692 | loss=4.0098 | ppl=55.13 | lr=1.19e-04 | throughput=122,256 tok/s (OK)
#     batch 1,400/7,000 | batch_size=346 | samples=818,939 | loss=4.0008 | ppl=54.64 | lr=1.19e-04 | throughput=121,754 tok/s (OK)
#     batch 2,100/7,000 | batch_size=391 | samples=1,231,716 | loss=4.0015 | ppl=54.68 | lr=1.18e-04 | throughput=122,230 tok/s (OK)
#     batch 2,800/7,000 | batch_size=214 | samples=1,632,607 | loss=4.0056 | ppl=54.90 | lr=1.18e-04 | throughput=121,997 tok/s (OK)
#     batch 3,500/7,000 | batch_size=321 | samples=2,033,754 | loss=4.0092 | ppl=55.10 | lr=1.18e-04 | throughput=122,671 tok/s (OK)
#     batch 4,200/7,000 | batch_size=600 | samples=2,444,815 | loss=4.0106 | ppl=55.18 | lr=1.17e-04 | throughput=122,680 tok/s (OK)
#     batch 4,900/7,000 | batch_size=290 | samples=2,852,106 | loss=4.0117 | ppl=55.24 | lr=1.17e-04 | throughput=122,570 tok/s (OK)
#     batch 5,600/7,000 | batch_size=375 | samples=3,277,726 | loss=4.0100 | ppl=55.15 | lr=1.16e-04 | throughput=122,187 tok/s (OK)
#     batch 6,300/7,000 | batch_size=900 | samples=3,687,860 | loss=4.0100 | ppl=55.15 | lr=1.16e-04 | throughput=122,178 tok/s (OK)
#     batch 7,000/7,000 | batch_size=428 | samples=4,103,335 | loss=4.0107 | ppl=55.19 | lr=1.16e-04 | throughput=122,613 tok/s (OK)
# 10M | epoch=16 | train_loss=4.0107 | train_ppl=55.19 | val_loss=2.7072 | val_ppl=14.99 | epoch_tps=122,309 (OK) | peak_mem=5.75 GB | epoch_time=421.2s
#     batch 1/7,000 | batch_size=1500 | samples=1,500 | loss=3.3975 | ppl=29.89 | lr=1.16e-04 | throughput=73,737 tok/s (LOW)
#     batch 700/7,000 | batch_size=642 | samples=410,828 | loss=3.9928 | ppl=54.21 | lr=1.15e-04 | throughput=122,021 tok/s (OK)
#     batch 1,400/7,000 | batch_size=500 | samples=832,643 | loss=3.9866 | ppl=53.87 | lr=1.15e-04 | throughput=121,935 tok/s (OK)
#     batch 2,100/7,000 | batch_size=450 | samples=1,244,303 | loss=3.9910 | ppl=54.11 | lr=1.15e-04 | throughput=122,254 tok/s (OK)
#     batch 2,800/7,000 | batch_size=450 | samples=1,634,102 | loss=4.0003 | ppl=54.61 | lr=1.14e-04 | throughput=122,646 tok/s (OK)
#     batch 3,500/7,000 | batch_size=750 | samples=2,044,094 | loss=4.0026 | ppl=54.74 | lr=1.14e-04 | throughput=122,838 tok/s (OK)
#     batch 4,200/7,000 | batch_size=818 | samples=2,447,142 | loss=4.0049 | ppl=54.87 | lr=1.14e-04 | throughput=122,170 tok/s (OK)
#     batch 4,900/7,000 | batch_size=409 | samples=2,865,172 | loss=4.0035 | ppl=54.79 | lr=1.13e-04 | throughput=121,904 tok/s (OK)
#     batch 5,600/7,000 | batch_size=391 | samples=3,277,205 | loss=4.0039 | ppl=54.81 | lr=1.13e-04 | throughput=122,082 tok/s (OK)
#     batch 6,300/7,000 | batch_size=1000 | samples=3,686,138 | loss=4.0043 | ppl=54.83 | lr=1.13e-04 | throughput=121,952 tok/s (OK)
#     batch 7,000/7,000 | batch_size=360 | samples=4,088,141 | loss=4.0050 | ppl=54.87 | lr=1.12e-04 | throughput=122,536 tok/s (OK)
# 10M | epoch=17 | train_loss=4.0050 | train_ppl=54.87 | val_loss=2.6987 | val_ppl=14.86 | epoch_tps=122,221 (OK) | peak_mem=5.74 GB | epoch_time=421.6s
#     batch 1/7,000 | batch_size=529 | samples=529 | loss=3.9251 | ppl=50.66 | lr=1.12e-04 | throughput=89,858 tok/s (LOW)
#     batch 700/7,000 | batch_size=529 | samples=401,776 | loss=3.9929 | ppl=54.21 | lr=1.12e-04 | throughput=121,823 tok/s (OK)
#     batch 1,400/7,000 | batch_size=134 | samples=821,301 | loss=3.9943 | ppl=54.29 | lr=1.12e-04 | throughput=121,999 tok/s (OK)
#     batch 2,100/7,000 | batch_size=750 | samples=1,232,277 | loss=3.9968 | ppl=54.42 | lr=1.11e-04 | throughput=121,813 tok/s (OK)
#     batch 2,800/7,000 | batch_size=391 | samples=1,626,721 | loss=4.0003 | ppl=54.62 | lr=1.11e-04 | throughput=122,171 tok/s (OK)
#     batch 3,500/7,000 | batch_size=692 | samples=2,031,289 | loss=4.0010 | ppl=54.65 | lr=1.11e-04 | throughput=122,531 tok/s (OK)
#     batch 4,200/7,000 | batch_size=391 | samples=2,448,755 | loss=4.0001 | ppl=54.60 | lr=1.10e-04 | throughput=122,176 tok/s (OK)
#     batch 4,900/7,000 | batch_size=1125 | samples=2,858,088 | loss=4.0006 | ppl=54.63 | lr=1.10e-04 | throughput=121,987 tok/s (OK)
#     batch 5,600/7,000 | batch_size=1500 | samples=3,269,464 | loss=4.0007 | ppl=54.63 | lr=1.10e-04 | throughput=121,729 tok/s (OK)
#     batch 6,300/7,000 | batch_size=310 | samples=3,673,692 | loss=4.0006 | ppl=54.63 | lr=1.09e-04 | throughput=121,792 tok/s (OK)
#     batch 7,000/7,000 | batch_size=562 | samples=4,088,319 | loss=3.9995 | ppl=54.57 | lr=1.09e-04 | throughput=122,187 tok/s (OK)
# 10M | epoch=18 | train_loss=3.9995 | train_ppl=54.57 | val_loss=2.6929 | val_ppl=14.77 | epoch_tps=122,014 (OK) | peak_mem=5.75 GB | epoch_time=422.2s
#     batch 1/7,000 | batch_size=1500 | samples=1,500 | loss=3.4482 | ppl=31.44 | lr=1.09e-04 | throughput=88,057 tok/s (LOW)
#     batch 700/7,000 | batch_size=1125 | samples=412,967 | loss=3.9802 | ppl=53.53 | lr=1.09e-04 | throughput=122,080 tok/s (OK)
#     batch 1,400/7,000 | batch_size=642 | samples=827,584 | loss=3.9798 | ppl=53.51 | lr=1.09e-04 | throughput=121,860 tok/s (OK)
#     batch 2,100/7,000 | batch_size=473 | samples=1,247,170 | loss=3.9797 | ppl=53.50 | lr=1.08e-04 | throughput=121,985 tok/s (OK)
#     batch 2,800/7,000 | batch_size=473 | samples=1,644,307 | loss=3.9860 | ppl=53.84 | lr=1.08e-04 | throughput=121,942 tok/s (OK)
#     batch 3,500/7,000 | batch_size=529 | samples=2,057,621 | loss=3.9870 | ppl=53.90 | lr=1.08e-04 | throughput=121,797 tok/s (OK)
#     batch 4,200/7,000 | batch_size=900 | samples=2,468,119 | loss=3.9892 | ppl=54.01 | lr=1.07e-04 | throughput=122,968 tok/s (OK)
#     batch 4,900/7,000 | batch_size=1000 | samples=2,861,623 | loss=3.9932 | ppl=54.23 | lr=1.07e-04 | throughput=122,168 tok/s (OK)
#     batch 5,600/7,000 | batch_size=102 | samples=3,265,363 | loss=3.9939 | ppl=54.27 | lr=1.07e-04 | throughput=121,605 tok/s (OK)
#     batch 6,300/7,000 | batch_size=321 | samples=3,669,119 | loss=3.9948 | ppl=54.31 | lr=1.06e-04 | throughput=121,300 tok/s (OK)
#     batch 7,000/7,000 | batch_size=642 | samples=4,075,940 | loss=3.9951 | ppl=54.33 | lr=1.06e-04 | throughput=121,756 tok/s (OK)
# 10M | epoch=19 | train_loss=3.9951 | train_ppl=54.33 | val_loss=2.6892 | val_ppl=14.72 | epoch_tps=121,938 (OK) | peak_mem=5.75 GB | epoch_time=422.5s
#     batch 1/7,000 | batch_size=600 | samples=600 | loss=3.9050 | ppl=49.65 | lr=1.06e-04 | throughput=82,480 tok/s (LOW)
#     batch 700/7,000 | batch_size=333 | samples=408,038 | loss=3.9805 | ppl=53.54 | lr=1.06e-04 | throughput=122,188 tok/s (OK)
#     batch 1,400/7,000 | batch_size=250 | samples=817,979 | loss=3.9798 | ppl=53.50 | lr=1.06e-04 | throughput=122,145 tok/s (OK)
#     batch 2,100/7,000 | batch_size=225 | samples=1,218,880 | loss=3.9856 | ppl=53.82 | lr=1.05e-04 | throughput=122,266 tok/s (OK)
#     batch 2,800/7,000 | batch_size=562 | samples=1,642,004 | loss=3.9832 | ppl=53.69 | lr=1.05e-04 | throughput=121,843 tok/s (OK)
#     batch 3,500/7,000 | batch_size=692 | samples=2,061,788 | loss=3.9816 | ppl=53.60 | lr=1.05e-04 | throughput=121,773 tok/s (OK)
#     batch 4,200/7,000 | batch_size=692 | samples=2,467,415 | loss=3.9831 | ppl=53.68 | lr=1.05e-04 | throughput=121,900 tok/s (OK)
#     batch 4,900/7,000 | batch_size=900 | samples=2,865,181 | loss=3.9859 | ppl=53.84 | lr=1.04e-04 | throughput=122,144 tok/s (OK)
#     batch 5,600/7,000 | batch_size=346 | samples=3,286,759 | loss=3.9850 | ppl=53.78 | lr=1.04e-04 | throughput=121,106 tok/s (OK)
#     batch 6,300/7,000 | batch_size=562 | samples=3,686,881 | loss=3.9873 | ppl=53.91 | lr=1.04e-04 | throughput=121,614 tok/s (OK)
#     batch 7,000/7,000 | batch_size=900 | samples=4,097,356 | loss=3.9874 | ppl=53.92 | lr=1.04e-04 | throughput=122,572 tok/s (OK)
# 10M | epoch=20 | train_loss=3.9874 | train_ppl=53.92 | val_loss=2.6910 | val_ppl=14.75 | epoch_tps=121,945 (OK) | peak_mem=5.75 GB | epoch_time=422.5s
# 10M average throughput: 121,913 tok/s | target=100,000 (OK)
# Saved: cache/checkpoints/final_10m_model.pt
#
# ============================================================
# Sample Inferences
# ============================================================
#
# EN: How are you?
# TE: ఎలా ఉన్నావ్ ?
#
# EN: The weather is nice today.
# TE: ఈ రోజు వాతావరణం చాలా బాగుంటుంది.
#
# EN: Machine translation is a challenging problem.
# TE: యంత్ర అనువాదం ఒక సవాలు సమస్య.
#
# EN: India is a country with diverse languages.
# TE: భారతదేశం విభిన్న భాషలున్న దేశం.
#
# EN: I am learning Telugu.
# TE: తెలుగు నేర్చుకుంటున్నాను.
#
# ========================================================================
# Training 30M | cfg={'d_model': 512, 'nhead': 8, 'num_enc_layers': 4, 'num_dec_layers': 4, 'd_ff': 512, 'dropout': 0.1} | initial_policy={'max_tokens': 6200, 'grad_accum': 4}
# ========================================================================
# Attempt 1: max_tokens=6200, grad_accum=4
# Samples: train=4,936,998 | val=4,928
# Batches: train=12,275 | val=14
# Initial LR: 5.00e-04 | grad_accum=4
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 30M: target=30,000,000 | actual=33,214,464 | error=+3,214,464 (+10.71%)
# Optimizer mode: fused
#     batch 1/7,000 | batch_size=112 | samples=112 | loss=10.5011 | ppl=36354.14 | lr=1.67e-07 | throughput=21,215 tok/s (LOW)
#     batch 700/7,000 | batch_size=885 | samples=279,103 | loss=8.9221 | ppl=7495.66 | lr=2.92e-05 | throughput=63,673 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=563 | samples=564,157 | loss=8.4068 | ppl=4477.29 | lr=5.83e-05 | throughput=63,444 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=364 | samples=851,881 | loss=8.0707 | ppl=3199.29 | lr=8.75e-05 | throughput=63,735 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=57 | samples=1,128,163 | loss=7.7867 | ppl=2408.30 | lr=1.17e-04 | throughput=63,816 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=387 | samples=1,409,102 | loss=7.5158 | ppl=1836.83 | lr=1.46e-04 | throughput=63,750 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=620 | samples=1,693,977 | loss=7.2800 | ppl=1450.97 | lr=1.75e-04 | throughput=63,652 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=413 | samples=1,967,936 | loss=7.0789 | ppl=1186.66 | lr=2.04e-04 | throughput=63,856 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=155 | samples=2,252,018 | loss=6.8982 | ppl=990.48 | lr=2.33e-04 | throughput=63,752 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=516 | samples=2,529,257 | loss=6.7412 | ppl=846.60 | lr=2.63e-04 | throughput=63,830 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=221 | samples=2,818,699 | loss=6.5986 | ppl=734.09 | lr=2.92e-04 | throughput=63,418 tok/s (LOW)
# 30M | epoch=1 | train_loss=6.5986 | train_ppl=734.09 | val_loss=4.1675 | val_ppl=64.56 | epoch_tps=63,674 (LOW) | peak_mem=5.26 GB | epoch_time=556.9s
#     batch 1/7,000 | batch_size=151 | samples=151 | loss=6.0673 | ppl=431.51 | lr=2.92e-04 | throughput=57,883 tok/s (LOW)
#     batch 700/7,000 | batch_size=516 | samples=275,235 | loss=5.2183 | ppl=184.63 | lr=3.21e-04 | throughput=63,739 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=221 | samples=557,676 | loss=5.1523 | ppl=172.83 | lr=3.50e-04 | throughput=63,843 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=364 | samples=840,849 | loss=5.0907 | ppl=162.50 | lr=3.79e-04 | throughput=63,836 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=269 | samples=1,116,463 | loss=5.0461 | ppl=155.42 | lr=4.08e-04 | throughput=63,869 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=688 | samples=1,395,895 | loss=5.0049 | ppl=149.14 | lr=4.37e-04 | throughput=63,909 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=121 | samples=1,669,260 | loss=4.9669 | ppl=143.59 | lr=4.67e-04 | throughput=63,991 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=81 | samples=1,948,707 | loss=4.9292 | ppl=138.27 | lr=4.96e-04 | throughput=63,375 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=688 | samples=2,234,262 | loss=4.8905 | ppl=133.02 | lr=4.88e-04 | throughput=63,648 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=281 | samples=2,518,313 | loss=4.8530 | ppl=128.12 | lr=4.75e-04 | throughput=63,886 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=516 | samples=2,792,382 | loss=4.8202 | ppl=123.99 | lr=4.63e-04 | throughput=63,675 tok/s (LOW)
# 30M | epoch=2 | train_loss=4.8202 | train_ppl=123.99 | val_loss=3.2353 | val_ppl=25.41 | epoch_tps=63,776 (LOW) | peak_mem=5.27 GB | epoch_time=556.1s
#     batch 1/7,000 | batch_size=151 | samples=151 | loss=5.1062 | ppl=165.04 | lr=4.63e-04 | throughput=60,375 tok/s (LOW)
#     batch 700/7,000 | batch_size=281 | samples=277,736 | loss=4.4306 | ppl=83.98 | lr=4.52e-04 | throughput=63,688 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=140 | samples=563,221 | loss=4.4015 | ppl=81.57 | lr=4.41e-04 | throughput=63,764 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=387 | samples=840,626 | loss=4.3805 | ppl=79.88 | lr=4.32e-04 | throughput=63,942 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=258 | samples=1,127,578 | loss=4.3561 | ppl=77.95 | lr=4.23e-04 | throughput=63,819 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=620 | samples=1,405,168 | loss=4.3411 | ppl=76.79 | lr=4.14e-04 | throughput=63,886 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=206 | samples=1,686,395 | loss=4.3222 | ppl=75.35 | lr=4.06e-04 | throughput=63,718 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=221 | samples=1,970,301 | loss=4.3055 | ppl=74.11 | lr=3.98e-04 | throughput=63,835 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=119 | samples=2,259,411 | loss=4.2888 | ppl=72.88 | lr=3.91e-04 | throughput=63,734 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=213 | samples=2,543,480 | loss=4.2740 | ppl=71.81 | lr=3.84e-04 | throughput=63,745 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=885 | samples=2,828,309 | loss=4.2607 | ppl=70.86 | lr=3.78e-04 | throughput=63,874 tok/s (LOW)
# 30M | epoch=3 | train_loss=4.2607 | train_ppl=70.86 | val_loss=2.8631 | val_ppl=17.52 | epoch_tps=63,800 (LOW) | peak_mem=5.28 GB | epoch_time=555.6s
#     batch 1/7,000 | batch_size=516 | samples=516 | loss=3.8306 | ppl=46.09 | lr=3.78e-04 | throughput=44,748 tok/s (LOW)
#     batch 700/7,000 | batch_size=200 | samples=270,093 | loss=4.1028 | ppl=60.51 | lr=3.72e-04 | throughput=63,841 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=167 | samples=555,844 | loss=4.0850 | ppl=59.44 | lr=3.66e-04 | throughput=63,739 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=163 | samples=837,640 | loss=4.0779 | ppl=59.02 | lr=3.60e-04 | throughput=63,684 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=281 | samples=1,120,090 | loss=4.0710 | ppl=58.62 | lr=3.55e-04 | throughput=63,713 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=187 | samples=1,398,668 | loss=4.0674 | ppl=58.41 | lr=3.50e-04 | throughput=63,833 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=442 | samples=1,677,696 | loss=4.0625 | ppl=58.12 | lr=3.45e-04 | throughput=63,778 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=563 | samples=1,955,619 | loss=4.0576 | ppl=57.83 | lr=3.40e-04 | throughput=64,143 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=158 | samples=2,241,426 | loss=4.0517 | ppl=57.49 | lr=3.36e-04 | throughput=63,675 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=200 | samples=2,526,358 | loss=4.0443 | ppl=57.07 | lr=3.31e-04 | throughput=63,909 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=620 | samples=2,798,964 | loss=4.0409 | ppl=56.88 | lr=3.27e-04 | throughput=63,979 tok/s (LOW)
# 30M | epoch=4 | train_loss=4.0409 | train_ppl=56.88 | val_loss=2.7268 | val_ppl=15.28 | epoch_tps=63,825 (LOW) | peak_mem=5.26 GB | epoch_time=555.7s
#     batch 1/7,000 | batch_size=563 | samples=563 | loss=3.6908 | ppl=40.08 | lr=3.27e-04 | throughput=47,061 tok/s (LOW)
#     batch 700/7,000 | batch_size=155 | samples=277,819 | loss=3.9441 | ppl=51.63 | lr=3.23e-04 | throughput=63,927 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=147 | samples=550,525 | loss=3.9451 | ppl=51.68 | lr=3.19e-04 | throughput=63,888 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=134 | samples=842,598 | loss=3.9357 | ppl=51.20 | lr=3.16e-04 | throughput=63,607 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=413 | samples=1,121,024 | loss=3.9381 | ppl=51.32 | lr=3.12e-04 | throughput=63,703 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=213 | samples=1,396,223 | loss=3.9380 | ppl=51.32 | lr=3.09e-04 | throughput=64,065 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=248 | samples=1,680,339 | loss=3.9350 | ppl=51.16 | lr=3.05e-04 | throughput=63,772 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=476 | samples=1,957,192 | loss=3.9331 | ppl=51.07 | lr=3.02e-04 | throughput=63,957 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=344 | samples=2,249,108 | loss=3.9288 | ppl=50.85 | lr=2.99e-04 | throughput=63,405 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=269 | samples=2,528,166 | loss=3.9267 | ppl=50.74 | lr=2.96e-04 | throughput=64,020 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=364 | samples=2,804,128 | loss=3.9252 | ppl=50.67 | lr=2.93e-04 | throughput=63,965 tok/s (LOW)
# 30M | epoch=5 | train_loss=3.9252 | train_ppl=50.67 | val_loss=2.6313 | val_ppl=13.89 | epoch_tps=63,827 (LOW) | peak_mem=5.27 GB | epoch_time=555.4s
#     batch 1/7,000 | batch_size=387 | samples=387 | loss=3.7842 | ppl=44.00 | lr=2.93e-04 | throughput=57,323 tok/s (LOW)
#     batch 700/7,000 | batch_size=281 | samples=278,321 | loss=3.8524 | ppl=47.11 | lr=2.90e-04 | throughput=64,008 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=476 | samples=558,557 | loss=3.8542 | ppl=47.19 | lr=2.87e-04 | throughput=63,784 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=269 | samples=824,838 | loss=3.8607 | ppl=47.50 | lr=2.84e-04 | throughput=64,136 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=476 | samples=1,109,417 | loss=3.8597 | ppl=47.45 | lr=2.82e-04 | throughput=63,772 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=563 | samples=1,395,335 | loss=3.8588 | ppl=47.41 | lr=2.79e-04 | throughput=63,698 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=775 | samples=1,682,324 | loss=3.8571 | ppl=47.33 | lr=2.77e-04 | throughput=63,859 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=476 | samples=1,971,174 | loss=3.8539 | ppl=47.18 | lr=2.74e-04 | throughput=63,584 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=476 | samples=2,249,813 | loss=3.8535 | ppl=47.16 | lr=2.72e-04 | throughput=63,378 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=344 | samples=2,515,399 | loss=3.8542 | ppl=47.19 | lr=2.70e-04 | throughput=64,052 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=364 | samples=2,795,128 | loss=3.8527 | ppl=47.12 | lr=2.67e-04 | throughput=63,926 tok/s (LOW)
# 30M | epoch=6 | train_loss=3.8527 | train_ppl=47.12 | val_loss=2.5768 | val_ppl=13.16 | epoch_tps=63,818 (LOW) | peak_mem=5.26 GB | epoch_time=555.7s
#     batch 1/7,000 | batch_size=413 | samples=413 | loss=3.7189 | ppl=41.22 | lr=2.67e-04 | throughput=54,222 tok/s (LOW)
#     batch 700/7,000 | batch_size=129 | samples=271,763 | loss=3.8077 | ppl=45.05 | lr=2.65e-04 | throughput=63,833 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=221 | samples=556,470 | loss=3.8019 | ppl=44.79 | lr=2.63e-04 | throughput=63,551 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=172 | samples=840,755 | loss=3.8011 | ppl=44.75 | lr=2.61e-04 | throughput=63,622 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=177 | samples=1,122,748 | loss=3.8027 | ppl=44.82 | lr=2.59e-04 | throughput=63,716 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=200 | samples=1,403,748 | loss=3.8010 | ppl=44.75 | lr=2.57e-04 | throughput=63,578 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=775 | samples=1,677,219 | loss=3.8029 | ppl=44.83 | lr=2.55e-04 | throughput=63,718 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=563 | samples=1,962,204 | loss=3.8014 | ppl=44.76 | lr=2.53e-04 | throughput=63,756 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=387 | samples=2,244,201 | loss=3.8005 | ppl=44.72 | lr=2.51e-04 | throughput=63,775 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=688 | samples=2,520,903 | loss=3.8008 | ppl=44.73 | lr=2.49e-04 | throughput=63,933 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=93 | samples=2,798,379 | loss=3.8004 | ppl=44.72 | lr=2.47e-04 | throughput=63,965 tok/s (LOW)
# 30M | epoch=7 | train_loss=3.8004 | train_ppl=44.72 | val_loss=2.5380 | val_ppl=12.65 | epoch_tps=63,742 (LOW) | peak_mem=5.27 GB | epoch_time=556.2s
#     batch 1/7,000 | batch_size=200 | samples=200 | loss=3.8877 | ppl=48.80 | lr=2.47e-04 | throughput=57,143 tok/s (LOW)
#     batch 700/7,000 | batch_size=516 | samples=281,156 | loss=3.7475 | ppl=42.41 | lr=2.46e-04 | throughput=63,853 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=248 | samples=571,957 | loss=3.7452 | ppl=42.32 | lr=2.44e-04 | throughput=63,776 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=281 | samples=854,442 | loss=3.7477 | ppl=42.42 | lr=2.42e-04 | throughput=63,838 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=885 | samples=1,138,643 | loss=3.7502 | ppl=42.53 | lr=2.41e-04 | throughput=63,783 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=229 | samples=1,414,112 | loss=3.7529 | ppl=42.65 | lr=2.39e-04 | throughput=63,825 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=75 | samples=1,695,141 | loss=3.7548 | ppl=42.73 | lr=2.37e-04 | throughput=63,966 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=516 | samples=1,980,170 | loss=3.7556 | ppl=42.76 | lr=2.36e-04 | throughput=63,796 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=688 | samples=2,266,255 | loss=3.7559 | ppl=42.77 | lr=2.34e-04 | throughput=63,607 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=344 | samples=2,544,217 | loss=3.7566 | ppl=42.80 | lr=2.33e-04 | throughput=63,889 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=885 | samples=2,831,968 | loss=3.7558 | ppl=42.77 | lr=2.31e-04 | throughput=63,630 tok/s (LOW)
# 30M | epoch=8 | train_loss=3.7558 | train_ppl=42.77 | val_loss=2.5054 | val_ppl=12.25 | epoch_tps=63,795 (LOW) | peak_mem=5.28 GB | epoch_time=555.8s
#     batch 1/7,000 | batch_size=238 | samples=238 | loss=3.7788 | ppl=43.76 | lr=2.31e-04 | throughput=53,668 tok/s (LOW)
#     batch 700/7,000 | batch_size=126 | samples=275,504 | loss=3.7212 | ppl=41.31 | lr=2.30e-04 | throughput=63,797 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=281 | samples=562,808 | loss=3.7192 | ppl=41.23 | lr=2.29e-04 | throughput=63,707 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=476 | samples=833,783 | loss=3.7250 | ppl=41.47 | lr=2.27e-04 | throughput=63,887 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=885 | samples=1,118,309 | loss=3.7248 | ppl=41.46 | lr=2.26e-04 | throughput=63,699 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=688 | samples=1,406,234 | loss=3.7240 | ppl=41.43 | lr=2.25e-04 | throughput=63,731 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=163 | samples=1,689,280 | loss=3.7253 | ppl=41.48 | lr=2.23e-04 | throughput=63,835 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=295 | samples=1,964,040 | loss=3.7271 | ppl=41.56 | lr=2.22e-04 | throughput=63,980 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=103 | samples=2,259,694 | loss=3.7250 | ppl=41.47 | lr=2.21e-04 | throughput=63,464 tok/s (LOW)
# ...
#     batch 1,400/7,000 | batch_size=228 | samples=282,164 | loss=3.6598 | ppl=38.85 | lr=2.77e-04 | throughput=35,314 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=246 | samples=430,279 | loss=3.6532 | ppl=38.60 | lr=2.75e-04 | throughput=35,472 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=64 | samples=572,879 | loss=3.6557 | ppl=38.70 | lr=2.74e-04 | throughput=35,557 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=533 | samples=719,280 | loss=3.6560 | ppl=38.71 | lr=2.73e-04 | throughput=35,390 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=213 | samples=868,792 | loss=3.6531 | ppl=38.59 | lr=2.72e-04 | throughput=35,345 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=188 | samples=1,016,859 | loss=3.6525 | ppl=38.57 | lr=2.71e-04 | throughput=35,410 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=246 | samples=1,163,831 | loss=3.6531 | ppl=38.59 | lr=2.70e-04 | throughput=35,387 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=246 | samples=1,307,755 | loss=3.6538 | ppl=38.62 | lr=2.68e-04 | throughput=35,554 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=200 | samples=1,455,255 | loss=3.6525 | ppl=38.57 | lr=2.67e-04 | throughput=35,224 tok/s (LOW)
# 60M | epoch=12 | train_loss=3.6525 | train_ppl=38.57 | val_loss=2.3812 | val_ppl=10.82 | epoch_tps=35,417 (LOW) | peak_mem=4.61 GB | epoch_time=516.4s
#     batch 1/7,000 | batch_size=123 | samples=123 | loss=3.7720 | ppl=43.47 | lr=2.67e-04 | throughput=30,693 tok/s (LOW)
#     batch 700/7,000 | batch_size=246 | samples=146,401 | loss=3.6179 | ppl=37.26 | lr=2.66e-04 | throughput=35,281 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=246 | samples=290,990 | loss=3.6225 | ppl=37.43 | lr=2.65e-04 | throughput=35,364 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=290 | samples=439,834 | loss=3.6220 | ppl=37.41 | lr=2.64e-04 | throughput=35,297 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=400 | samples=584,311 | loss=3.6235 | ppl=37.47 | lr=2.63e-04 | throughput=35,290 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=320 | samples=726,205 | loss=3.6254 | ppl=37.54 | lr=2.62e-04 | throughput=35,691 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=128 | samples=868,973 | loss=3.6259 | ppl=37.56 | lr=2.61e-04 | throughput=35,367 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=72 | samples=1,014,101 | loss=3.6259 | ppl=37.56 | lr=2.60e-04 | throughput=35,404 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=114 | samples=1,155,183 | loss=3.6271 | ppl=37.60 | lr=2.59e-04 | throughput=35,470 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=139 | samples=1,296,698 | loss=3.6279 | ppl=37.63 | lr=2.58e-04 | throughput=35,530 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=177 | samples=1,440,758 | loss=3.6285 | ppl=37.65 | lr=2.57e-04 | throughput=35,360 tok/s (LOW)
# 60M | epoch=13 | train_loss=3.6285 | train_ppl=37.65 | val_loss=2.3629 | val_ppl=10.62 | epoch_tps=35,404 (LOW) | peak_mem=4.61 GB | epoch_time=516.7s
#     batch 1/7,000 | batch_size=355 | samples=355 | loss=3.4555 | ppl=31.68 | lr=2.57e-04 | throughput=28,054 tok/s (LOW)
#     batch 700/7,000 | batch_size=290 | samples=150,806 | loss=3.5865 | ppl=36.11 | lr=2.56e-04 | throughput=35,292 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=200 | samples=297,966 | loss=3.5918 | ppl=36.30 | lr=2.55e-04 | throughput=35,174 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=168 | samples=439,474 | loss=3.5961 | ppl=36.46 | lr=2.54e-04 | throughput=35,466 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=320 | samples=581,006 | loss=3.6005 | ppl=36.62 | lr=2.53e-04 | throughput=35,691 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=355 | samples=734,608 | loss=3.5983 | ppl=36.53 | lr=2.52e-04 | throughput=35,392 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=290 | samples=875,580 | loss=3.6009 | ppl=36.63 | lr=2.51e-04 | throughput=35,333 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=200 | samples=1,021,199 | loss=3.6023 | ppl=36.68 | lr=2.50e-04 | throughput=35,569 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=106 | samples=1,172,128 | loss=3.6016 | ppl=36.66 | lr=2.49e-04 | throughput=35,218 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=110 | samples=1,320,813 | loss=3.6013 | ppl=36.65 | lr=2.48e-04 | throughput=35,197 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=168 | samples=1,463,103 | loss=3.6027 | ppl=36.70 | lr=2.47e-04 | throughput=35,404 tok/s (LOW)
# 60M | epoch=14 | train_loss=3.6027 | train_ppl=36.70 | val_loss=2.3421 | val_ppl=10.40 | epoch_tps=35,371 (LOW) | peak_mem=4.61 GB | epoch_time=517.1s
#     batch 1/7,000 | batch_size=96 | samples=96 | loss=3.5573 | ppl=35.07 | lr=2.47e-04 | throughput=31,156 tok/s (LOW)
#     batch 700/7,000 | batch_size=213 | samples=145,372 | loss=3.5752 | ppl=35.70 | lr=2.47e-04 | throughput=35,512 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=188 | samples=289,337 | loss=3.5786 | ppl=35.82 | lr=2.46e-04 | throughput=35,308 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=188 | samples=436,893 | loss=3.5754 | ppl=35.71 | lr=2.45e-04 | throughput=35,229 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=145 | samples=586,261 | loss=3.5743 | ppl=35.67 | lr=2.44e-04 | throughput=35,115 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=266 | samples=731,999 | loss=3.5752 | ppl=35.70 | lr=2.43e-04 | throughput=35,501 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=66 | samples=877,820 | loss=3.5771 | ppl=35.77 | lr=2.42e-04 | throughput=35,364 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=88 | samples=1,018,289 | loss=3.5793 | ppl=35.85 | lr=2.41e-04 | throughput=35,493 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=59 | samples=1,167,004 | loss=3.5791 | ppl=35.84 | lr=2.41e-04 | throughput=35,176 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=100 | samples=1,308,901 | loss=3.5807 | ppl=35.90 | lr=2.40e-04 | throughput=35,653 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=128 | samples=1,453,364 | loss=3.5814 | ppl=35.92 | lr=2.39e-04 | throughput=35,312 tok/s (LOW)
# 60M | epoch=15 | train_loss=3.5814 | train_ppl=35.92 | val_loss=2.3263 | val_ppl=10.24 | epoch_tps=35,365 (LOW) | peak_mem=4.60 GB | epoch_time=517.3s
#     batch 1/7,000 | batch_size=68 | samples=68 | loss=3.5579 | ppl=35.09 | lr=2.39e-04 | throughput=30,027 tok/s (LOW)
#     batch 700/7,000 | batch_size=69 | samples=144,261 | loss=3.5481 | ppl=34.75 | lr=2.38e-04 | throughput=35,406 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=533 | samples=292,666 | loss=3.5505 | ppl=34.83 | lr=2.37e-04 | throughput=35,237 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=128 | samples=437,841 | loss=3.5525 | ppl=34.90 | lr=2.37e-04 | throughput=35,373 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=266 | samples=580,481 | loss=3.5545 | ppl=34.97 | lr=2.36e-04 | throughput=35,511 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=188 | samples=729,226 | loss=3.5563 | ppl=35.03 | lr=2.35e-04 | throughput=35,279 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=290 | samples=878,221 | loss=3.5575 | ppl=35.08 | lr=2.34e-04 | throughput=35,315 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=123 | samples=1,024,313 | loss=3.5587 | ppl=35.12 | lr=2.34e-04 | throughput=35,192 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=457 | samples=1,166,379 | loss=3.5606 | ppl=35.18 | lr=2.33e-04 | throughput=35,449 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=110 | samples=1,306,911 | loss=3.5617 | ppl=35.22 | lr=2.32e-04 | throughput=35,550 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=355 | samples=1,452,818 | loss=3.5619 | ppl=35.23 | lr=2.31e-04 | throughput=35,271 tok/s (LOW)
# 60M | epoch=16 | train_loss=3.5619 | train_ppl=35.23 | val_loss=2.3077 | val_ppl=10.05 | epoch_tps=35,357 (LOW) | peak_mem=4.60 GB | epoch_time=517.3s
#     batch 1/7,000 | batch_size=228 | samples=228 | loss=3.5319 | ppl=34.19 | lr=2.31e-04 | throughput=30,633 tok/s (LOW)
#     batch 700/7,000 | batch_size=106 | samples=148,493 | loss=3.5333 | ppl=34.24 | lr=2.31e-04 | throughput=35,393 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=266 | samples=297,411 | loss=3.5312 | ppl=34.17 | lr=2.30e-04 | throughput=35,162 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=128 | samples=440,522 | loss=3.5376 | ppl=34.38 | lr=2.29e-04 | throughput=35,431 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=66 | samples=585,720 | loss=3.5396 | ppl=34.45 | lr=2.29e-04 | throughput=35,484 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=290 | samples=730,291 | loss=3.5408 | ppl=34.49 | lr=2.28e-04 | throughput=35,493 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=114 | samples=874,593 | loss=3.5428 | ppl=34.56 | lr=2.27e-04 | throughput=35,374 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=177 | samples=1,023,025 | loss=3.5428 | ppl=34.56 | lr=2.27e-04 | throughput=35,395 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=106 | samples=1,170,589 | loss=3.5436 | ppl=34.59 | lr=2.26e-04 | throughput=35,483 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=320 | samples=1,320,750 | loss=3.5437 | ppl=34.59 | lr=2.25e-04 | throughput=35,341 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=82 | samples=1,465,266 | loss=3.5436 | ppl=34.59 | lr=2.25e-04 | throughput=35,702 tok/s (LOW)
# 60M | epoch=17 | train_loss=3.5436 | train_ppl=34.59 | val_loss=2.2973 | val_ppl=9.95 | epoch_tps=35,424 (LOW) | peak_mem=4.60 GB | epoch_time=516.4s
#     batch 1/7,000 | batch_size=69 | samples=69 | loss=3.5552 | ppl=35.00 | lr=2.25e-04 | throughput=30,871 tok/s (LOW)
#     batch 700/7,000 | batch_size=168 | samples=146,067 | loss=3.5215 | ppl=33.83 | lr=2.24e-04 | throughput=35,214 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=266 | samples=294,069 | loss=3.5191 | ppl=33.75 | lr=2.23e-04 | throughput=35,309 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=200 | samples=438,580 | loss=3.5254 | ppl=33.97 | lr=2.23e-04 | throughput=35,450 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=355 | samples=583,447 | loss=3.5258 | ppl=33.98 | lr=2.22e-04 | throughput=35,407 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=200 | samples=723,785 | loss=3.5285 | ppl=34.07 | lr=2.21e-04 | throughput=35,306 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=69 | samples=867,754 | loss=3.5291 | ppl=34.09 | lr=2.21e-04 | throughput=35,398 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=152 | samples=1,017,208 | loss=3.5288 | ppl=34.08 | lr=2.20e-04 | throughput=35,203 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=177 | samples=1,154,722 | loss=3.5316 | ppl=34.18 | lr=2.19e-04 | throughput=35,753 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=168 | samples=1,298,309 | loss=3.5328 | ppl=34.22 | lr=2.19e-04 | throughput=35,685 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=66 | samples=1,446,878 | loss=3.5329 | ppl=34.22 | lr=2.18e-04 | throughput=35,251 tok/s (LOW)
# 60M | epoch=18 | train_loss=3.5329 | train_ppl=34.22 | val_loss=2.2821 | val_ppl=9.80 | epoch_tps=35,396 (LOW) | peak_mem=4.60 GB | epoch_time=516.7s
#     batch 1/7,000 | batch_size=246 | samples=246 | loss=3.2829 | ppl=26.65 | lr=2.18e-04 | throughput=30,687 tok/s (LOW)
#     batch 700/7,000 | batch_size=160 | samples=145,094 | loss=3.5013 | ppl=33.16 | lr=2.18e-04 | throughput=35,397 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=228 | samples=300,058 | loss=3.4970 | ppl=33.02 | lr=2.17e-04 | throughput=35,255 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=246 | samples=444,609 | loss=3.5020 | ppl=33.18 | lr=2.16e-04 | throughput=35,549 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=133 | samples=590,860 | loss=3.5045 | ppl=33.26 | lr=2.16e-04 | throughput=35,423 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=61 | samples=734,362 | loss=3.5074 | ppl=33.36 | lr=2.15e-04 | throughput=35,445 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=168 | samples=882,949 | loss=3.5076 | ppl=33.37 | lr=2.15e-04 | throughput=35,243 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=32 | samples=1,031,807 | loss=3.5083 | ppl=33.39 | lr=2.14e-04 | throughput=35,403 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=69 | samples=1,176,193 | loss=3.5105 | ppl=33.46 | lr=2.14e-04 | throughput=35,395 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=128 | samples=1,323,632 | loss=3.5112 | ppl=33.49 | lr=2.13e-04 | throughput=35,298 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=145 | samples=1,465,401 | loss=3.5132 | ppl=33.55 | lr=2.12e-04 | throughput=35,344 tok/s (LOW)
# 60M | epoch=19 | train_loss=3.5132 | train_ppl=33.55 | val_loss=2.2756 | val_ppl=9.73 | epoch_tps=35,374 (LOW) | peak_mem=4.60 GB | epoch_time=517.1s
#     batch 1/7,000 | batch_size=152 | samples=152 | loss=3.4428 | ppl=31.28 | lr=2.12e-04 | throughput=28,275 tok/s (LOW)
#     batch 700/7,000 | batch_size=290 | samples=149,547 | loss=3.4855 | ppl=32.64 | lr=2.12e-04 | throughput=35,291 tok/s (LOW)
#     batch 1,400/7,000 | batch_size=123 | samples=297,838 | loss=3.4876 | ppl=32.71 | lr=2.11e-04 | throughput=35,344 tok/s (LOW)
#     batch 2,100/7,000 | batch_size=133 | samples=441,827 | loss=3.4920 | ppl=32.85 | lr=2.11e-04 | throughput=35,441 tok/s (LOW)
#     batch 2,800/7,000 | batch_size=188 | samples=587,145 | loss=3.4946 | ppl=32.94 | lr=2.10e-04 | throughput=35,339 tok/s (LOW)
#     batch 3,500/7,000 | batch_size=266 | samples=729,789 | loss=3.4988 | ppl=33.07 | lr=2.10e-04 | throughput=35,448 tok/s (LOW)
#     batch 4,200/7,000 | batch_size=110 | samples=877,163 | loss=3.4994 | ppl=33.10 | lr=2.09e-04 | throughput=35,485 tok/s (LOW)
#     batch 4,900/7,000 | batch_size=103 | samples=1,021,422 | loss=3.5008 | ppl=33.14 | lr=2.09e-04 | throughput=35,347 tok/s (LOW)
#     batch 5,600/7,000 | batch_size=110 | samples=1,166,497 | loss=3.5021 | ppl=33.18 | lr=2.08e-04 | throughput=35,474 tok/s (LOW)
#     batch 6,300/7,000 | batch_size=71 | samples=1,313,666 | loss=3.5029 | ppl=33.21 | lr=2.08e-04 | throughput=35,171 tok/s (LOW)
#     batch 7,000/7,000 | batch_size=106 | samples=1,462,148 | loss=3.5038 | ppl=33.24 | lr=2.07e-04 | throughput=35,388 tok/s (LOW)
# 60M | epoch=20 | train_loss=3.5038 | train_ppl=33.24 | val_loss=2.2708 | val_ppl=9.69 | epoch_tps=35,371 (LOW) | peak_mem=4.60 GB | epoch_time=517.0s
# 60M average throughput: 35,343 tok/s | target=100,000 (LOW)
# Note: throughput for 60M is below target. Increase max_tokens for this model if VRAM headroom allows.
# Saved: cache/checkpoints/final_60m_model.pt
#
# ============================================================
# Sample Inferences
# ============================================================
#
# EN: How are you?
# TE: ఎలా వున్నావ్ ?
#
# EN: The weather is nice today.
# TE: ఈ రోజు వాతావరణం చాలా బాగుంది.
#
# EN: Machine translation is a challenging problem.
# TE: యంత్రం అనువాదం ఒక సవాలుదాయక సమస్య.
#
# EN: India is a country with diverse languages.
# TE: భారతదేశం విభిన్న భాషలతో కూడిన దేశం.
#
# EN: I am learning Telugu.
# TE: తెలుగు నేర్చుకుంటున్నా.
#   model  target_m  actual_params  param_error_pct  max_tokens  grad_accum  \
# 0   10M        10       12145664        21.456640        9000           2
# 1   30M        30       33214464        10.714880        6200           4
# 2   50M        50       51076096         2.152192        4400           6
# 3   60M        60       65804288         9.673813        3200           8
#
#    best_epoch  best_val_loss  best_val_ppl   runtime_sec  avg_tokens_per_sec  \
# 0          19       2.689222     14.720214   8451.999371       121913.134966
# 1          19       2.353866     10.526188  11126.329921        63738.616330
# 2          20       2.278070      9.757833  11295.694273        44537.781904
# 3          20       2.270808      9.687226  10350.231892        35342.601675
#
#    target_tokens_per_sec  target_met  oom_retries optimizer_mode  \
# 0                 100000        True            0          fused
# 1                 100000       False            0          fused
# 2                 100000       False            0          fused
# 3                 100000       False            0          fused
#
#         amp_dtype                            checkpoint
# 0  torch.bfloat16  cache/checkpoints/final_10m_model.pt
# 1  torch.bfloat16  cache/checkpoints/final_30m_model.pt
# 2  torch.bfloat16  cache/checkpoints/final_50m_model.pt
# 3  torch.bfloat16  cache/checkpoints/final_60m_model.pt

# %%
sample_texts = [
    # 1. Very short / conversational
    "hi",
    "hello",
    "thanks",
    "ok",
    "yes",
    "no",
    "bye",
    "good morning",
    "what's up",
    "see you",

    # 2. Slang / informal
    "bro what are you doing",
    "this is crazy",
    "no way",
    "that’s awesome",
    "I’m kinda tired",
    "gonna go now",
    "lemme check",
    "this sucks",
    "chill man",
    "you serious?",

    # 3. Negation traps
    "I don’t think this will work",
    "He is not unhappy",
    "This is not bad at all",
    "I never said that",
    "They didn’t finish the work",

    # 4. Ambiguous meaning
    "He saw her duck",
    "I found the book interesting",
    "They are flying planes",
    "She left him yesterday",
    "Visiting relatives can be boring",

    # 5. Long + complex
    "Although the system seems efficient, it fails under heavy load conditions.",
    "If you had told me earlier, I would have helped you.",
    "Despite multiple warnings, he continued to ignore the issue.",
    "The project, which was delayed multiple times, was finally completed.",
    "Even if it rains, we will continue with the event.",

    # 6. Questions
    "What are you doing right now?",
    "Why did you say that?",
    "How does this system work?",
    "Can you explain this again?",
    "Where did you learn this?",

    # 7. Numbers / data
    "I have 2 apples and 3 oranges.",
    "The temperature is 35 degrees today.",
    "This costs 500 rupees.",
    "He scored 95 out of 100.",
    "The meeting is at 10:30 AM.",

    # 8. Mixed / tricky grammar
    "Not only did he win, but he also broke the record.",
    "The more you practice, the better you get.",
    "She is smarter than she looks.",
    "Hardly had he arrived when it started raining.",
    "No sooner did we leave than it began to snow.",
]
#Prints a header and loops over TARGET_MILLIONS (10M, 30M, 50M, 60M).
print("Running sample inferences on all saved models...")
for target_m in TARGET_MILLIONS:
    ckpt_path = CHECKPOINT_DIR / f"final_{target_m}m_model.pt" #Constructs checkpoint path final_{target_m}m_model.pt
    if not ckpt_path.exists():
        print(f"Checkpoint for {target_m}M model not found at {ckpt_path}")
        continue

    print(f"\n============================================================")
    print(f"Loading {target_m}M model from {ckpt_path.name}...")
    print(f"============================================================")

    try:
        ckpt = torch.load(ckpt_path, map_location=DEVICE, weights_only=True)
    except TypeError:
        ckpt = torch.load(ckpt_path, map_location=DEVICE)
    #Builds NMTTrans with saved config, loads its state dict, and sets eval()
    model = NMTTrans(vocab_size=VOCAB_SIZE, **ckpt["config"]).to(DEVICE)#
    model.load_state_dict(ckpt["model_state_dict"])
    model.eval()

    run_sample_inferences(model, sample_texts)

    del model, ckpt
    gc.collect()
    if DEVICE.type == "cuda":
        torch.cuda.empty_cache()
# Out:
# Running sample inferences on all saved models...
#
# ============================================================
# Loading 10M model from final_10m_model.pt...
# ============================================================
# /tmp/ipykernel_2657198/2246320394.py:27: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# ============================================================
# Sample Inferences
# ============================================================
#
# EN: hi
# TE: హి.
#
# EN: hello
# TE: హలో
#
# EN: thanks
# TE: ధన్యవాదాలు
#
# EN: ok
# TE: సరే.
#
# EN: yes
# TE: అవును.
#
# EN: no
# TE: నెం.
#
# EN: bye
# TE: బై బై
#
# EN: good morning
# TE: మంచి ఉదయం.
#
# EN: what's up
# TE: ఏం ఉంది?
#
# EN: see you
# TE: మీరు చూడండి
#
# EN: bro what are you doing
# TE: మీరు ఏమి చేస్తున్నారు బ్రో
#
# EN: this is crazy
# TE: ఇది పిచ్చి.
#
# EN: no way
# TE: మార్గం లేదు
#
# EN: that’s awesome
# TE: అది అద్భుతం
#
# EN: I’m kinda tired
# TE: నేను దయతో అలసిపోతున్నాను
#
# EN: gonna go now
# TE: ఇప్పుడు గొన్న
#
# EN: lemme check
# TE: లేమ్మ్ తనిఖీ
#
# EN: this sucks
# TE: ఈ సూక్లు
#
# EN: chill man
# TE: కూల్ మ్యాన్
#
# EN: you serious?
# TE: సీరియస్ గా ఉన్నారా?
#
# EN: I don’t think this will work
# TE: ఈ పని జరుగుతుందని నేను అనుకోను
#
# EN: He is not unhappy
# TE: ఆయన అసంతృప్తితో లేరు
#
# EN: This is not bad at all
# TE: ఇది అస్సలు చెడ్డది కాదు
#
# EN: I never said that
# TE: నేను ఎప్పుడూ చెప్పలేదు
#
# EN: They didn’t finish the work
# TE: వారు పని పూర్తి కాలేదు
#
# EN: He saw her duck
# TE: ఆమె బాకు చూసింది
#
# EN: I found the book interesting
# TE: పుస్తకం ఆసక్తికరంగా మారింది
#
# EN: They are flying planes
# TE: అవి విమానాలుగా ఉంటాయి
#
# EN: She left him yesterday
# TE: ఆమె నిన్ననే ఆమెను వదిలింది
#
# EN: Visiting relatives can be boring
# TE: సందర్శించే బంధువులు
#
# EN: Although the system seems efficient, it fails under heavy load conditions.
# TE: వ్యవస్థ సమర్థవంతంగా ఉన్నప్పటికీ, ఇది భారీ లోడు పరిస్థితుల్లో విఫలమవుతుంది.
#
# EN: If you had told me earlier, I would have helped you.
# TE: మీరు నాకు ముందే చెప్పినట్లయితే, నేను మీకు సహాయం చేస్తాను.
#
# EN: Despite multiple warnings, he continued to ignore the issue.
# TE: అనేక హెచ్చరికలు ఉన్నప్పటికీ, అతను ఈ సమస్యను విస్మరించాడు.
#
# EN: The project, which was delayed multiple times, was finally completed.
# TE: ఈ ప్రాజెక్టు చాలా సార్లు వాయిదా పడుతూ వచ్చింది.
#
# EN: Even if it rains, we will continue with the event.
# TE: వర్షం వస్తే, ఈ సంఘటనతో పాటు కొనసాగిస్తామని చెప్పారు.
#
# EN: What are you doing right now?
# TE: ఇప్పుడు ఏం చేస్తున్నారు?
#
# EN: Why did you say that?
# TE: ఎందుకు అలా చెప్పావు?
#
# EN: How does this system work?
# TE: ఈ వ్యవస్థ ఎలా పనిచేస్తుంది?
#
# EN: Can you explain this again?
# TE: మరి ఈ విషయాన్ని మీరు వివరించగలరా?
#
# EN: Where did you learn this?
# TE: ఎక్కడ ఈ విషయం నేర్చుకుంది?
#
# EN: I have 2 apples and 3 oranges.
# TE: నాకు 2 ఆపిల్స్ మరియు 3 ఆరెంజ్ ఉన్నాయి.
#
# EN: The temperature is 35 degrees today.
# TE: ఈ రోజు ఉష్ణోగ్రత 35 డిగ్రీల సెల్సియస్.
#
# EN: This costs 500 rupees.
# TE: 500 రూబిళ్లు ఖర్చవుతుంది.
#
# EN: He scored 95 out of 100.
# TE: 100 బంతుల్లో 95 పరుగులు చేశాడు.
#
# EN: The meeting is at 10:30 AM.
# TE: ఉదయం 10:30 గంటలకు ఈ సమావేశం జరిగింది.
#
# EN: Not only did he win, but he also broke the record.
# TE: కేవలం విజయం మాత్రమే కాదు, రికార్డు కూడా బద్దలు కొట్టాడు.
#
# EN: The more you practice, the better you get.
# TE: మీరు మరింత సాధన, మీరు పొందడానికి ఉత్తమ ఉంది.
#
# EN: She is smarter than she looks.
# TE: ఆమె కంటే స్మార్ట్ గా ఉంటుంది.
#
# EN: Hardly had he arrived when it started raining.
# TE: వర్షం ప్రారంభమైన వెంటనే ఆయన అక్కడికి చేరుకున్నారు.
#
# EN: No sooner did we leave than it began to snow.
# TE: మేము మంచుతో ప్రారంభమైనప్పటి నుండి తప్పుకున్నాము.
#
# ============================================================
# Loading 30M model from final_30m_model.pt...
# ============================================================
#
# ============================================================
# Sample Inferences
# ============================================================
#
# EN: hi
# TE: హాయ్
#
# EN: hello
# TE: హలో.
#
# EN: thanks
# TE: ధన్యవాదాలు.
#
# EN: ok
# TE: సరే.
#
# EN: yes
# TE: అవును.
#
# EN: no
# TE: లేదు.
#
# EN: bye
# TE: బై
#
# EN: good morning
# TE: గుడ్ మార్నింగ్
#
# EN: what's up
# TE: ఏం ఉంది?
#
# EN: see you
# TE: చూడండి.
#
# EN: bro what are you doing
# TE: మీరు ఏమి చేస్తున్నారో బ్రో
#
# EN: this is crazy
# TE: ఇది పిచ్చి
#
# EN: no way
# TE: దారి లేదు.
#
# EN: that’s awesome
# TE: ఇది అద్భుతం
#
# EN: I’m kinda tired
# TE: నేను అలసిపోతాను
#
# EN: gonna go now
# TE: ఇప్పుడు వెళ్ళండి గొన్న
#
# EN: lemme check
# TE: లెమ్మె చెక్
#
# EN: this sucks
# TE: ఈ సూక్లు
#
# EN: chill man
# TE: కూల్ మ్యాన్
#
# EN: you serious?
# TE: సీరియస్ గా ఉన్నారా?
#
# EN: I don’t think this will work
# TE: ఇది పని చేస్తుందని నేను అనుకోవడం లేదు
#
# EN: He is not unhappy
# TE: ఆయన అసంతృప్తి లేదు
#
# EN: This is not bad at all
# TE: ఇది ఏమాత్రం తప్పు కాదు
#
# EN: I never said that
# TE: నేను ఎప్పుడూ చెప్పలేదు
#
# EN: They didn’t finish the work
# TE: వారు పని పూర్తి చేయలేదు
#
# EN: He saw her duck
# TE: ఆమె తన వంక చూసింది
#
# EN: I found the book interesting
# TE: పుస్తకం ఆసక్తికరంగా ఉంది
#
# EN: They are flying planes
# TE: వారు ఫ్లైయింగ్ విమానాలు
#
# EN: She left him yesterday
# TE: ఆమె నిన్ననే ఆమెను వదిలింది
#
# EN: Visiting relatives can be boring
# TE: బంధువులను సందర్శించడం చికాకు కలిగించవచ్చు
#
# EN: Although the system seems efficient, it fails under heavy load conditions.
# TE: ఈ వ్యవస్థ సమర్థవంతంగా ఉన్నప్పటికీ, అది తీవ్రమైన లోడ్ పరిస్థితుల్లో విఫలమవుతుంది.
#
# EN: If you had told me earlier, I would have helped you.
# TE: మీరు ముందు నాతో చెప్పినట్లయితే నేను మీకు సహాయం చేస్తాను.
#
# EN: Despite multiple warnings, he continued to ignore the issue.
# TE: అనేక హెచ్చరికలు ఉన్నప్పటికీ, అతను ఈ సమస్యను నిర్లక్ష్యం చేయలేదు.
#
# EN: The project, which was delayed multiple times, was finally completed.
# TE: పలుసార్లు వాయిదా వేసిన ఈ ప్రాజెక్టు చివరకు పూర్తి అయ్యింది.
#
# EN: Even if it rains, we will continue with the event.
# TE: వర్షం వస్తేనే ఈ కార్యక్రమం కొనసాగిస్తామని తెలిపారు.
#
# EN: What are you doing right now?
# TE: ఇప్పుడు మీరు ఏమి చేస్తున్నారు?
#
# EN: Why did you say that?
# TE: ఎందుకు అలా చెప్పావు?
#
# EN: How does this system work?
# TE: ఈ వ్యవస్థ ఎలా పనిచేస్తుంది?
#
# EN: Can you explain this again?
# TE: ఈ విషయాన్ని మరోసారి వివరించగలరా?
#
# EN: Where did you learn this?
# TE: ఎక్కడ నేర్చుకున్నారు?
#
# EN: I have 2 apples and 3 oranges.
# TE: నేను 2 ఆపిల్ మరియు 3 ఆకులను కలిగి.
#
# EN: The temperature is 35 degrees today.
# TE: ఈ రోజు ఉష్ణోగ్రత 35 డిగ్రీల ఉంది.
#
# EN: This costs 500 rupees.
# TE: 500 రూబిళ్లు ఖర్చు.
#
# EN: He scored 95 out of 100.
# TE: 100 బంతుల్లో 95 పరుగులు చేశాడు.
#
# EN: The meeting is at 10:30 AM.
# TE: ఉదయం 10.30 గంటలకు ఈ సమావేశం జరిగింది.
#
# EN: Not only did he win, but he also broke the record.
# TE: అంతేకాదు ఈ ఘనతను కూడా సొంతం చేసుకున్నాడు.
#
# EN: The more you practice, the better you get.
# TE: మీరు మరింత సాధన, మీరు పొందండి.
#
# EN: She is smarter than she looks.
# TE: ఆమె కంటే తెలివైనది.
#
# EN: Hardly had he arrived when it started raining.
# TE: వర్షం ప్రారంభమైనప్పుడు ఆయన అక్కడికి రాలేదు.
#
# EN: No sooner did we leave than it began to snow.
# TE: మేము మంచుతో కప్పడం ప్రారంభించిన దానికంటే త్వరగా బయలుదేరాము.
#
# ============================================================
# Loading 50M model from final_50m_model.pt...
# ============================================================
#
# ============================================================
# Sample Inferences
# ============================================================
#
# EN: hi
# TE:  ⁇ హా
#
# EN: hello
# TE: హలో
#
# EN: thanks
# TE: ధన్యవాదాలు
#
# EN: ok
# TE: సరే.
#
# EN: yes
# TE: అవును .
#
# EN: no
# TE: వద్దు
#
# EN: bye
# TE: బై
#
# EN: good morning
# TE: గుడ్ మార్నింగ్
#
# EN: what's up
# TE: ఏంటా . ?
#
# EN: see you
# TE: మీరు చూడండి
#
# EN: bro what are you doing
# TE: """అబ్బే ఏం చేస్తున్నావ్?"
#
# EN: this is crazy
# TE: ఇది వెర్రితనం
#
# EN: no way
# TE: దారి లేదు
#
# EN: that’s awesome
# TE: అది అద్భుతం
#
# EN: I’m kinda tired
# TE: నేను అలసిపోతున్నాను
#
# EN: gonna go now
# TE: ఇప్పుడు వెళ్ళు గొన్న
#
# EN: lemme check
# TE: లెమ్మ్మ్ చెక్
#
# EN: this sucks
# TE: ఈ విడ్డూరం
#
# EN: chill man
# TE: చల్లని మనిషి
#
# EN: you serious?
# TE: సీరియస్ గా తీసుకున్నారా?
#
# EN: I don’t think this will work
# TE: ఇది పని చేస్తుందని అనుకోను
#
# EN: He is not unhappy
# TE: ఆయన అసంతృప్తితో ఉన్నారు
#
# EN: This is not bad at all
# TE: ఇది ఏమాత్రం మంచిది కాదు
#
# EN: I never said that
# TE: నేను ఎప్పుడూ చెప్పలేదు
#
# EN: They didn’t finish the work
# TE: వారు పని పూర్తి చేయలేదు
#
# EN: He saw her duck
# TE: ఆమె బాతును చూసింది
#
# EN: I found the book interesting
# TE: నేను పుస్తకం ఆసక్తికరమైనది
#
# EN: They are flying planes
# TE: అవి ఫ్లయింగ్ విమానాలు
#
# EN: She left him yesterday
# TE: నిన్ననే ఆమె అక్కడి నుంచి వెళ్లిపోయింది
#
# EN: Visiting relatives can be boring
# TE: బంధువులను సందర్శించడం వల్ల చికాకు కలుగుతుంది
#
# EN: Although the system seems efficient, it fails under heavy load conditions.
# TE: ఈ వ్యవస్థ సమర్థవంతంగా ఉన్నప్పటికీ, ఇది భారీ లోడ్ పరిస్థితులలో విఫలమవుతుంది.
#
# EN: If you had told me earlier, I would have helped you.
# TE: మీరు నాకు ముందే చెప్పినట్లయితే, నేను మీకు సహాయం చేస్తాను.
#
# EN: Despite multiple warnings, he continued to ignore the issue.
# TE: అనేక హెచ్చరికలను హెచ్చరించినా, ఆయన ఆ సమస్యను విస్మరించకుండా కొనసాగాడు.
#
# EN: The project, which was delayed multiple times, was finally completed.
# TE: ఇప్పటికే పలుమార్లు వాయిదా పడిన ఈ ప్రాజెక్టు పూర్తి అయ్యింది.
#
# EN: Even if it rains, we will continue with the event.
# TE: వర్షాలు కురుస్తే కూడా ఈ కార్యక్రమాన్ని కొనసాగిస్తాం.
#
# EN: What are you doing right now?
# TE: ఇప్పుడు ఏం చేస్తున్నారు?
#
# EN: Why did you say that?
# TE: ఎందుకు అలా చెప్పావు?
#
# EN: How does this system work?
# TE: ఎలా ఈ వ్యవస్థ పని చేస్తుంది?
#
# EN: Can you explain this again?
# TE: మీరు మళ్ళీ ఈ వివరణ ఇవ్వవచ్చు?
#
# EN: Where did you learn this?
# TE: ఈ విషయం ఎక్కడ నేర్చుకున్నారు?
#
# EN: I have 2 apples and 3 oranges.
# TE: నాకు 2 ఆపిల్స్ మరియు 3 నారింజలు ఉన్నాయి.
#
# EN: The temperature is 35 degrees today.
# TE: ఈ సమయంలో ఉష్ణోగ్రత 35 డిగ్రీల ఉంది.
#
# EN: This costs 500 rupees.
# TE: దీని ధర 500 రూబిళ్లు ఉంది.
#
# EN: He scored 95 out of 100.
# TE: 100 బంతుల్లో 95 పరుగులు చేశాడు.
#
# EN: The meeting is at 10:30 AM.
# TE: ఉదయం 10.30 గంటలకు సమావేశం జరుగుతుంది.
#
# EN: Not only did he win, but he also broke the record.
# TE: ఒక్క విజయం మాత్రమే కాదు, రికార్డు కూడా బద్దలు కొట్టాడు.
#
# EN: The more you practice, the better you get.
# TE: ఎంత ఎక్కువ సాధన చేస్తే అంత మంచిది.
#
# EN: She is smarter than she looks.
# TE: ఆమె తన లుక్ కంటే తెలివైనది.
#
# EN: Hardly had he arrived when it started raining.
# TE: వర్షం ప్రారంభమైనప్పుడు ఆయన రావడం లేదు.
#
# EN: No sooner did we leave than it began to snow.
# TE: మంచు ప్రారంభమైన దానికంటే త్వరగా మేము వదిలి వెళ్ళలేదు.
#
# ============================================================
# Loading 60M model from final_60m_model.pt...
# ============================================================
#
# ============================================================
# Sample Inferences
# ============================================================
#
# EN: hi
# TE: ాహ్
#
# EN: hello
# TE: హలో
#
# EN: thanks
# TE: ధన్యవాదాలు
#
# EN: ok
# TE: సరే...
#
# EN: yes
# TE: అవునండి
#
# EN: no
# TE: వద్దు
#
# EN: bye
# TE: బై
#
# EN: good morning
# TE: గుడ్ మార్నింగ్
#
# EN: what's up
# TE: ఏం జేస్తరు?
#
# EN: see you
# TE: మీరు చూడండి.
#
# EN: bro what are you doing
# TE: బ్రో ఏం చేస్తున్నావు?
#
# EN: this is crazy
# TE: ఇది పిచ్చి
#
# EN: no way
# TE: మార్గం లేదు.
#
# EN: that’s awesome
# TE: అది అద్భుతం
#
# EN: I’m kinda tired
# TE: నేను అలసిపోతున్నాను
#
# EN: gonna go now
# TE: ఇప్పుడు వెళ్ళి గొన్న
#
# EN: lemme check
# TE: లెమ్మె చెక్
#
# EN: this sucks
# TE: ఈ సూక్తులు
#
# EN: chill man
# TE: చల్ల మనిషి
#
# EN: you serious?
# TE: సీరియస్ గా ఉన్నారా?
#
# EN: I don’t think this will work
# TE: ఇది పని కాదు
#
# EN: He is not unhappy
# TE: ఆయన అసంతృప్తితో ఉన్నారు
#
# EN: This is not bad at all
# TE: ఇది ఎంతమాత్రం మంచిది కాదు
#
# EN: I never said that
# TE: నేను ఎప్పుడూ చెప్పలేదు
#
# EN: They didn’t finish the work
# TE: పనులు పూర్తి చేయలేదు
#
# EN: He saw her duck
# TE: ఆమె కళ్లెం చూశాడు
#
# EN: I found the book interesting
# TE: ఆ పుస్తకం నాకు ఆసక్తికరంగా అనిపించింది
#
# EN: They are flying planes
# TE: వారు విమానాల్లో ప్రయాణించారు
#
# EN: She left him yesterday
# TE: నిన్ననే ఆమె అక్కడి నుంచి వెళ్లిపోయింది
#
# EN: Visiting relatives can be boring
# TE: సందర్శించడం బంధువులకు చికాకు కలిగించవచ్చు
#
# EN: Although the system seems efficient, it fails under heavy load conditions.
# TE: ఈ వ్యవస్థ సమర్ధవంతంగా కనిపించినప్పటికీ, భారీ లోడ్ పరిస్థితులలో విఫలమవుతుంది.
#
# EN: If you had told me earlier, I would have helped you.
# TE: మీరు నాకు ముందే చెప్పినట్లయితే, నేను మీకు సహాయం చేస్తాను.
#
# EN: Despite multiple warnings, he continued to ignore the issue.
# TE: అనేక హెచ్చరికలు ఉన్నప్పటికీ, అతను ఈ సమస్యను విస్మరించాడు.
#
# EN: The project, which was delayed multiple times, was finally completed.
# TE: ఈ ప్రాజెక్టు ఇప్పటికే పలుమార్లు వాయిదా పడింది.
#
# EN: Even if it rains, we will continue with the event.
# TE: వర్షం వస్తే కూడా ఈ కార్యక్రమం కొనసాగుతుంది.
#
# EN: What are you doing right now?
# TE: ఇప్పుడు మీరు ఏమి చేస్తున్నారు?
#
# EN: Why did you say that?
# TE: ఎందుకు అలా అనాల్సి వచ్చింది?
#
# EN: How does this system work?
# TE: ఎలా ఈ వ్యవస్థ పని చేస్తుంది?
#
# EN: Can you explain this again?
# TE: ఈ విషయాన్ని మళ్లీ వివరించగలరా?
#
# EN: Where did you learn this?
# TE: ఎక్కడ ఈ విషయం తెలుసుకున్నారా?
#
# EN: I have 2 apples and 3 oranges.
# TE: నాకు 2 ఆపిల్స్ మరియు 3 నారింజ ఉన్నాయి.
#
# EN: The temperature is 35 degrees today.
# TE: ఈ రోజు ఉష్ణోగ్రత 35 డిగ్రీల సెల్సియస్.
#
# EN: This costs 500 rupees.
# TE: దీని ధర 500 రూబిళ్లు ఉంది.
#
# EN: He scored 95 out of 100.
# TE: 100 బంతుల్లో 95 పరుగులు చేశాడు.
#
# EN: The meeting is at 10:30 AM.
# TE: ఉదయం 10:30 గంటలకు సమావేశం జరగనుంది.
#
# EN: Not only did he win, but he also broke the record.
# TE: ఒక్క పరుగు మాత్రమే కాకుండా, అతను కూడా రికార్డు బద్దలు కొట్టాడు.
#
# EN: The more you practice, the better you get.
# TE: మీరు ఎంత ఎక్కువ ప్రాక్టీస్ చేస్తే అంత మంచిది.
#
# EN: She is smarter than she looks.
# TE: ఆమె చూడటానికి కంటే స్మార్ట్ గా ఉంటుంది.
#
# EN: Hardly had he arrived when it started raining.
# TE: వర్షం కురవడంతో ఆయన అక్కడికి రాలేదు.
#
# EN: No sooner did we leave than it began to snow.
# TE: మంచుతో కప్పడం మొదలుపెట్టినప్పటి నుండి మేము తప్ప మిగతావి కూడా వదలలేదు.

# %%
import warnings
from pathlib import Path
import sacrebleu
import torch

# Silence repeated Transformer mask warnings during large decode loops.
warnings.filterwarnings("ignore", category=UserWarning, message=".*key_padding_mask.*")

#helper to reconstruct a saved model 
def load_model(path, config):
    model = NMTTrans(vocab_size=VOCAB_SIZE, **config).to(DEVICE)
    try:
        checkpoint = torch.load(path, map_location=DEVICE, weights_only=True)
    except TypeError:
        checkpoint = torch.load(path, map_location=DEVICE)
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

#to filter out special tokens and decode the remaining IDs
def decode_clean(token_ids, sp_model):
    clean_ids = [int(t) for t in token_ids if int(t) not in (PAD_ID, BOS_ID, EOS_ID)]
    if not clean_ids:
        return ""
    return sp_model.decode(clean_ids)


@torch.inference_mode()
def compute_bleu(model, val_loader, sp_model, max_sentences=300):
    preds = []
    refs = []

    count = 0
    for src, tgt in val_loader:
        for i in range(src.size(0)):
            src_text = decode_clean(src[i].tolist(), sp_model)
            pred = greedy_decode(model, src_text, sp_model)
            ref = decode_clean(tgt[i].tolist(), sp_model)
            #for each source, decodes the input text, translates with greedy_decode, and decodes the reference
            preds.append(pred)
            refs.append(ref)

            count += 1
            if count >= max_sentences:
                break
        if count >= max_sentences:
            break

    bleu = sacrebleu.corpus_bleu(preds, [refs])
    return bleu.score


CHECKPOINT_DIR = Path("cache/checkpoints")

_, val_loader = make_loaders(max_tokens=2048)

models = {
    "10M": (CHECKPOINT_DIR / "final_10m_model.pt", validated_configs["10M"]),
    "30M": (CHECKPOINT_DIR / "final_30m_model.pt", validated_configs["30M"]),
    "50M": (CHECKPOINT_DIR / "final_50m_model.pt", validated_configs["50M"]),
    "60M": (CHECKPOINT_DIR / "final_60m_model.pt", validated_configs["60M"]),
}

bleu_scores = {}

for name, (path, cfg) in models.items():
    if not path.exists():
        print(f"{name} checkpoint not found: {path}")
        continue

    model = load_model(path, cfg)
    bleu = compute_bleu(model, val_loader, sp)
    bleu_scores[name] = bleu
    print(f"{name} BLEU: {bleu:.2f}")

    del model
    if DEVICE.type == "cuda":
        torch.cuda.empty_cache()
# Out:
# 10M BLEU: 16.09
# 30M BLEU: 20.05
# 50M BLEU: 18.82
# 60M BLEU: 12.63

# %%
import warnings
from pathlib import Path

import pandas as pd
import sacrebleu
import torch

# Silence noisy warnings during repeated decoding/model loading.
warnings.filterwarnings("ignore", category=UserWarning, message=".*key_padding_mask.*")
warnings.filterwarnings("ignore", category=UserWarning, message=".*enable_nested_tensor.*")

##helper to reconstruct a saved model
def load_model(path, config):
    model = NMTTrans(vocab_size=VOCAB_SIZE, **config).to(DEVICE)
    try:
        checkpoint = torch.load(path, map_location=DEVICE, weights_only=True)
    except TypeError:
        checkpoint = torch.load(path, map_location=DEVICE)
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

#to filter out special tokens and decode the remaining IDs
def decode_clean(token_ids, sp_model):
    clean_ids = [int(t) for t in token_ids if int(t) not in (PAD_ID, BOS_ID, EOS_ID)]
    if not clean_ids:
        return ""
    return sp_model.decode(clean_ids)


@torch.inference_mode()
def collect_preds_refs(model, val_loader, sp_model, max_sentences=1500):
    preds = []
    refs = []

    count = 0
    for src, tgt in val_loader:
        for i in range(src.size(0)):
            src_text = decode_clean(src[i].tolist(), sp_model)
            pred = greedy_decode(model, src_text, sp_model)
            ref = decode_clean(tgt[i].tolist(), sp_model)
            #for each source, decodes the input text, translates with greedy_decode, and decodes the reference
            preds.append(pred)
            refs.append(ref)

            count += 1
            if count >= max_sentences:
                return preds, refs
    return preds, refs


def normalize_column(values: pd.Series) -> pd.Series:
    vmin = values.min()
    vmax = values.max()
    if vmax <= vmin:
        return pd.Series([0.0] * len(values), index=values.index)
    return (values - vmin) / (vmax - vmin)


CHECKPOINT_DIR = Path("cache/checkpoints")
_, val_loader = make_loaders(max_tokens=2048)

models = {
    "10M": (CHECKPOINT_DIR / "final_10m_model.pt", validated_configs["10M"]),
    "30M": (CHECKPOINT_DIR / "final_30m_model.pt", validated_configs["30M"]),
    "50M": (CHECKPOINT_DIR / "final_50m_model.pt", validated_configs["50M"]),
    "60M": (CHECKPOINT_DIR / "final_60m_model.pt", validated_configs["60M"]),
}

EVAL_SENTENCES = 1500
rows = []
#For each model:
#loads the checkpointed model

for name, (path, cfg) in models.items():
    if not path.exists():
        print(f"{name} checkpoint not found: {path}")
        continue
    #character-level matching can reflect translation quality
    model = load_model(path, cfg)
    preds, refs = collect_preds_refs(model, val_loader, sp, max_sentences=EVAL_SENTENCES)
    #computes BLEU and chrF scores
    bleu = sacrebleu.corpus_bleu(preds, [refs]).score
    chrf = sacrebleu.corpus_chrf(preds, [refs]).score

    rows.append(
        {
            "model": name,
            "num_sentences": len(preds),
            "bleu": float(bleu),
            "chrf": float(chrf),
        }
    )

    print(f"{name} | BLEU={bleu:.2f} | chrF={chrf:.2f} | sentences={len(preds)}")

    del model
    if DEVICE.type == "cuda":
        torch.cuda.empty_cache()

score_df = pd.DataFrame(rows)
score_df["bleu_norm"] = normalize_column(score_df["bleu"])
score_df["chrf_norm"] = normalize_column(score_df["chrf"])
score_df["composite"] = 0.5 * score_df["bleu_norm"] + 0.5 * score_df["chrf_norm"]
score_df = score_df.sort_values(by="composite", ascending=False).reset_index(drop=True)

best_model = score_df.loc[0, "model"]
print(f"\nBest model by unbiased composite (BLEU+chrF): {best_model}")

score_df
# Out:
# 10M | BLEU=12.38 | chrF=41.29 | sentences=1500
# 30M | BLEU=15.01 | chrF=42.73 | sentences=1500
# 50M | BLEU=13.16 | chrF=42.65 | sentences=1500
# 60M | BLEU=13.13 | chrF=42.12 | sentences=1500
#
# Best model by unbiased composite (BLEU+chrF): 30M
#   model  num_sentences       bleu       chrf  bleu_norm  chrf_norm  composite
# 0   30M           1500  15.012157  42.726994   1.000000   1.000000   1.000000
# 1   50M           1500  13.161710  42.651627   0.295887   0.947644   0.621766
# 2   60M           1500  13.127239  42.120589   0.282771   0.578744   0.430757
# 3   10M           1500  12.384102  41.287479   0.000000   0.000000   0.000000
